# %%
import httpx
import os
from dotenv import load_dotenv
import pandas as pd

# %%
load_dotenv()
api_key= os.getenv("api_key")

# %%
headers = {
    "X-API-Key":api_key,
    "accept": "application/json"
}
session = httpx.AsyncClient(headers=headers)

# %%
url = "https://api.openaq.org/v3/locations?order_by=id&sort_order=asc&countries_id=135&limit=100&page=1"

# %%
response = await session.get(url=url)
result = response.json()

# %%
result
# Out:
# {'meta': {'name': 'openaq-api',
#   'website': '/',
#   'page': 1,
#   'limit': 100,
#   'found': 96},
#  'results': [{'id': 31,
#    'name': 'Wekerom-Riemterdijk',
#    'locality': 'Wekerom',
#    'timezone': 'Europe/Amsterdam',
#    'country': {'id': 135, 'code': 'NL', 'name': 'Netherlands'},
#    'owner': {'id': 4, 'name': 'Unknown Governmental Organization'},
#    'provider': {'id': 70, 'name': 'EEA'},
#    'isMobile': False,
#    'isMonitor': True,
#    'instruments': [{'id': 2, 'name': 'Government Monitor'}],
#    'sensors': [{'id': 4650,
#      'name': 'pm10 µg/m³',
#      'parameter': {'id': 1,
#       'name': 'pm10',
#       'units': 'µg/m³',
#       'displayName': 'PM10'}},
#     {'id': 4275693,
#      'name': 'no µg/m³',
#      'parameter': {'id': 19843,
#       'name': 'no',
#       'units': 'µg/m³',
#       'displayName': 'NO mass'}},
#     {'id': 4642,
#      'name': 'no2 µg/m³',
#      'parameter': {'id': 5,
#       'name': 'no2',
#       'units': 'µg/m³',
#       'displayName': 'NO₂ mass'}},
#     {'id': 50,
#      'name': 'pm25 µg/m³',
#      'parameter': {'id': 2,
#       'name': 'pm25',
#       'units': 'µg/m³',
#       'displayName': 'PM2.5'}},
#     {'id': 4649,
#      'name': 'o3 µg/m³',
#      'parameter': {'id': 3,
#       'name': 'o3',
#       'units': 'µg/m³',
#       'displayName': 'O₃ mass'}}],
#    'coordinates': {'latitude': 52.11162099964508,
#     'longitude': 5.708418999868416},
#    'licenses': None,
#    'bounds': [5.708418999868416,
#     52.11162099964508,
#     5.708418999868416,
#     52.11162099964508],
#    'distance': None,
#    'datetimeFirst': {'utc': '2016-01-30T01:00:00+00:00',
#     'local': '2016-01-30T02:00:00+01:00'},
#    'datetimeLast': {'utc': '2024-04-22T15:00:00+00:00',
#     'local': '2024-04-22T17:00:00+02:00'}},
#   {'id': 33,
#    'name': 'Zaanstad-Hemkade',
#    'locality': 'ZAANDAM',
#    'timezone': 'Europe/Amsterdam',
#    'country': {'id': 135, 'code': 'NL', 'name': 'Netherlands'},
#    'owner': {'id': 4, 'name': 'Unknown Governmental Organization'},
#    'provider': {'id': 70, 'name': 'EEA'},
#    'isMobile': False,
#    'isMonitor': True,
#    'instruments': [{'id': 2, 'name': 'Government Monitor'}],
#    'sensors': [{'id': 4612,
#      'name': 'pm10 µg/m³',
#      'parameter': {'id': 1,
#       'name': 'pm10',
#       'units': 'µg/m³',
#       'displayName': 'PM10'}},
#     {'id': 52,
#      'name': 'no2 µg/m³',
#      'parameter': {'id': 5,
#       'name': 'no2',
#       'units': 'µg/m³',
#       'displayName': 'NO₂ mass'}},
#     {'id': 4276093,
#      'name': 'no µg/m³',
#      'parameter': {'id': 19843,
#       'name': 'no',
#       'units': 'µg/m³',
#       'displayName': 'NO mass'}}],
#    'coordinates': {'latitude': 52.42022999959271,
#     'longitude': 4.832060000156797},
#    'licenses': None,
#    'bounds': [4.832060000156797,
#     52.42022999959271,
#     4.832060000156797,
#     52.42022999959271],
#    'distance': None,
#    'datetimeFirst': {'utc': '2016-01-30T01:00:00+00:00',
#     'local': '2016-01-30T02:00:00+01:00'},
#    'datetimeLast': {'utc': '2024-04-22T15:00:00+00:00',
#     'local': '2024-04-22T17:00:00+02:00'}},
#   {'id': 41,
#    'name': 'Groningen-Europaweg',
#    'locality': 'GRONINGEN',
#    'timezone': 'Europe/Amsterdam',
#    'country': {'id': 135, 'code': 'NL', 'name': 'Netherlands'},
#    'owner': {'id': 4, 'name': 'Unknown Governmental Organization'},
#    'provider': {'id': 70, 'name': 'EEA'},
#    'isMobile': False,
#    'isMonitor': True,
#    'instruments': [{'id': 2, 'name': 'Government Monitor'}],
#    'sensors': [{'id': 61,
#      'name': 'pm25 µg/m³',
#      'parameter': {'id': 2,
#       'name': 'pm25',
#       'units': 'µg/m³',
#       'displayName': 'PM2.5'}},
#     {'id': 4217,
#      'name': 'no2 µg/m³',
#      'parameter': {'id': 5,
#       'name': 'no2',
#       'units': 'µg/m³',
#       'displayName': 'NO₂ mass'}},
#     {'id': 4216,
#      'name': 'pm10 µg/m³',
#      'parameter': {'id': 1,
#       'name': 'pm10',
#       'units': 'µg/m³',
#       'displayName': 'PM10'}},
#     {'id': 4275972,
#      'name': 'no µg/m³',
#      'parameter': {'id': 19843,
#       'name': 'no',
#       'units': 'µg/m³',
#       'displayName': 'NO mass'}}],
#    'coordinates': {'latitude': 53.217795999418236,
#     'longitude': 6.578901000005765},
#    'licenses': None,
#    'bounds': [6.578901000005765,
#     53.217795999418236,
#     6.578901000005765,
#     53.217795999418236],
#    'distance': None,
#    'datetimeFirst': {'utc': '2016-01-30T01:00:00+00:00',
#     'local': '2016-01-30T02:00:00+01:00'},
#    'datetimeLast': {'utc': '2024-04-22T15:00:00+00:00',
#     'local': '2024-04-22T17:00:00+02:00'}},
#   {'id': 44,
#    'name': 'Heerlen-Jamboreepad',
#    'locality': 'Heerlen',
#    'timezone': 'Europe/Amsterdam',
#    'country': {'id': 135, 'code': 'NL', 'name': 'Netherlands'},
#    'owner': {'id': 4, 'name': 'Unknown Governmental Organization'},
#    'provider': {'id': 70, 'name': 'EEA'},
#    'isMobile': False,
#    'isMonitor': True,
#    'instruments': [{'id': 2, 'name': 'Government Monitor'}],
#    'sensors': [{'id': 64,
#      'name': 'no2 µg/m³',
#      'parameter': {'id': 5,
#       'name': 'no2',
#       'units': 'µg/m³',
#       'displayName': 'NO₂ mass'}},
#     {'id': 4275805,
#      'name': 'no µg/m³',
#      'parameter': {'id': 19843,
#       'name': 'no',
#       'units': 'µg/m³',
#       'displayName': 'NO mass'}},
#     {'id': 4198,
#      'name': 'pm10 µg/m³',
#      'parameter': {'id': 1,
#       'name': 'pm10',
#       'units': 'µg/m³',
#       'displayName': 'PM10'}},
#     {'id': 4194,
#      'name': 'o3 µg/m³',
#      'parameter': {'id': 3,
#       'name': 'o3',
#       'units': 'µg/m³',
#       'displayName': 'O₃ mass'}},
#     {'id': 4202,
#      'name': 'pm25 µg/m³',
#      'parameter': {'id': 2,
#       'name': 'pm25',
#       'units': 'µg/m³',
#       'displayName': 'PM2.5'}}],
#    'coordinates': {'latitude': 50.90031699963291,
#     'longitude': 5.986852999872599},
#    'licenses': None,
#    'bounds': [5.986852999872599,
#     50.90031699963291,
#     5.986852999872599,
#     50.90031699963291],
#    'distance': None,
#    'datetimeFirst': {'utc': '2016-01-30T01:00:00+00:00',
#     'local': '2016-01-30T02:00:00+01:00'},
#    'datetimeLast': {'utc': '2024-04-22T15:00:00+00:00',
#     'local': '2024-04-22T17:00:00+02:00'}},
#   {'id': 51,
#    'name': 'Wieringerwerf-Medemblikkerweg',
#    'locality': 'Wieringerwerf',
#    'timezone': 'Europe/Amsterdam',
#    'country': {'id': 135, 'code': 'NL', 'name': 'Netherlands'},
#    'owner': {'id': 4, 'name': 'Unknown Governmental Organization'},
#    'provider': {'id': 70, 'name': 'EEA'},
#    'isMobile': False,
#    'isMonitor': True,
#    'instruments': [{'id': 2, 'name': 'Government Monitor'}],
#    'sensors': [{'id': 4275809,
#      'name': 'no µg/m³',
#      'parameter': {'id': 19843,
#       'name': 'no',
#       'units': 'µg/m³',
#       'displayName': 'NO mass'}},
#     {'id': 4154,
#      'name': 'pm25 µg/m³',
#      'parameter': {'id': 2,
#       'name': 'pm25',
#       'units': 'µg/m³',
#       'displayName': 'PM2.5'}},
#     {'id': 72,
#      'name': 'no2 µg/m³',
#      'parameter': {'id': 5,
#       'name': 'no2',
#       'units': 'µg/m³',
#       'displayName': 'NO₂ mass'}},
#     {'id': 4158,
#      'name': 'pm10 µg/m³',
#      'parameter': {'id': 1,
#       'name': 'pm10',
#       'units': 'µg/m³',
#       'displayName': 'PM10'}},
#     {'id': 4162,
#      'name': 'o3 µg/m³',
#      'parameter': {'id': 3,
#       'name': 'o3',
#       'units': 'µg/m³',
#       'displayName': 'O₃ mass'}}],
#    'coordinates': {'latitude': 52.80365699946534,
#     'longitude': 5.050508999758845},
#    'licenses': None,
#    'bounds': [5.050508999758845,
#     52.80365699946534,
#     5.050508999758845,
#     52.80365699946534],
#    'distance': None,
#    'datetimeFirst': {'utc': '2016-01-30T01:00:00+00:00',
#     'local': '2016-01-30T02:00:00+01:00'},
#    'datetimeLast': {'utc': '2024-04-22T15:00:00+00:00',
#     'local': '2024-04-22T17:00:00+02:00'}},
#   {'id': 52,
#    'name': 'Rotterdam-Oost Sidelinge A13',
#    'locality': 'ROTTERDAM',
#    'timezone': 'Europe/Amsterdam',
#    'country': {'id': 135, 'code': 'NL', 'name': 'Netherlands'},
#    'owner': {'id': 4, 'name': 'Unknown Governmental Organization'},
#    'provider': {'id': 70, 'name': 'EEA'},
#    'isMobile': False,
#    'isMonitor': True,
#    'instruments': [{'id': 2, 'name': 'Government Monitor'}],
#    'sensors': [{'id': 73,
#      'name': 'pm25 µg/m³',
#      'parameter': {'id': 2,
#       'name': 'pm25',
#       'units': 'µg/m³',
#       'displayName': 'PM2.5'}},
#     {'id': 4299,
#      'name': 'no2 µg/m³',
#      'parameter': {'id': 5,
#       'name': 'no2',
#       'units': 'µg/m³',
#       'displayName': 'NO₂ mass'}},
#     {'id': 4276171,
#      'name': 'no µg/m³',
#      'parameter': {'id': 19843,
#       'name': 'no',
#       'units': 'µg/m³',
#       'displayName': 'NO mass'}},
#     {'id': 4300,
#      'name': 'pm10 µg/m³',
#      'parameter': {'id': 1,
#       'name': 'pm10',
#       'units': 'µg/m³',
#       'displayName': 'PM10'}}],
#    'coordinates': {'latitude': 51.9384719996572,
#     'longitude': 4.430691999983553},
#    'licenses': None,
#    'bounds': [4.430691999983553,
#     51.9384719996572,
#     4.430691999983553,
#     51.9384719996572],
#    'distance': None,
#    'datetimeFirst': {'utc': '2016-01-30T01:00:00+00:00',
#     'local': '2016-01-30T02:00:00+01:00'},
#    'datetimeLast': {'utc': '2024-04-22T15:00:00+00:00',
#     'local': '2024-04-22T17:00:00+02:00'}},
#   {'id': 55,
#    'name': 'Utrecht-Kardinaal de Jongweg',
#    'locality': 'Utrecht',
#    'timezone': 'Europe/Amsterdam',
#    'country': {'id': 135, 'code': 'NL', 'name': 'Netherlands'},
#    'owner': {'id': 4, 'name': 'Unknown Governmental Organization'},
#    'provider': {'id': 70, 'name': 'EEA'},
#    'isMobile': False,
#    'isMonitor': True,
#    'instruments': [{'id': 2, 'name': 'Government Monitor'}],
#    'sensors': [{'id': 4276081,
#      'name': 'no µg/m³',
#      'parameter': {'id': 19843,
#       'name': 'no',
#       'units': 'µg/m³',
#       'displayName': 'NO mass'}},
#     {'id': 4118,
#      'name': 'pm25 µg/m³',
#      'parameter': {'id': 2,
#       'name': 'pm25',
#       'units': 'µg/m³',
#       'displayName': 'PM2.5'}},
#     {'id': 1301475,
#      'name': 'o3 µg/m³',
#      'parameter': {'id': 3,
#       'name': 'o3',
#       'units': 'µg/m³',
#       'displayName': 'O₃ mass'}},
#     {'id': 77,
#      'name': 'pm10 µg/m³',
#      'parameter': {'id': 1,
#       'name': 'pm10',
#       'units': 'µg/m³',
#       'displayName': 'PM10'}},
#     {'id': 4117,
#      'name': 'no2 µg/m³',
#      'parameter': {'id': 5,
#       'name': 'no2',
#       'units': 'µg/m³',
#       'displayName': 'NO₂ mass'}}],
#    'coordinates': {'latitude': 52.10503099920887,
#     'longitude': 5.124464000283312},
#    'licenses': None,
#    'bounds': [5.124464000283312,
#     52.10503099920887,
#     5.124464000283312,
#     52.10503099920887],
#    'distance': None,
#    'datetimeFirst': {'utc': '2016-01-30T01:00:00+00:00',
#     'local': '2016-01-30T02:00:00+01:00'},
#    'datetimeLast': {'utc': '2024-04-22T15:00:00+00:00',
#     'local': '2024-04-22T17:00:00+02:00'}},
#   {'id': 58,
#    'name': 'Zegveld-Oude Meije',
#    'locality': 'Zegveld',
#    'timezone': 'Europe/Amsterdam',
#    'country': {'id': 135, 'code': 'NL', 'name': 'Netherlands'},
#    'owner': {'id': 4, 'name': 'Unknown Governmental Organization'},
#    'provider': {'id': 70, 'name': 'EEA'},
#    'isMobile': False,
#    'isMonitor': True,
#    'instruments': [{'id': 2, 'name': 'Government Monitor'}],
#    'sensors': [{'id': 4275687,
#      'name': 'no µg/m³',
#      'parameter': {'id': 19843,
#       'name': 'no',
#       'units': 'µg/m³',
#       'displayName': 'NO mass'}},
#     {'id': 4474,
#      'name': 'no2 µg/m³',
#      'parameter': {'id': 5,
#       'name': 'no2',
#       'units': 'µg/m³',
#       'displayName': 'NO₂ mass'}},
#     {'id': 85,
#      'name': 'co µg/m³',
#      'parameter': {'id': 4,
#       'name': 'co',
#       'units': 'µg/m³',
#       'displayName': 'CO mass'}},
#     {'id': 4355,
#      'name': 'pm10 µg/m³',
#      'parameter': {'id': 1,
#       'name': 'pm10',
#       'units': 'µg/m³',
#       'displayName': 'PM10'}},
#     {'id': 4690,
#      'name': 'o3 µg/m³',
#      'parameter': {'id': 3,
#       'name': 'o3',
#       'units': 'µg/m³',
#       'displayName': 'O₃ mass'}}],
#    'coordinates': {'latitude': 52.13794999941131,
#     'longitude': 4.83819000034937},
#    'licenses': None,
#    'bounds': [4.83819000034937,
#     52.13794999941131,
#     4.83819000034937,
#     52.13794999941131],
#    'distance': None,
#    'datetimeFirst': {'utc': '2016-01-30T01:00:00+00:00',
#     'local': '2016-01-30T02:00:00+01:00'},
#    'datetimeLast': {'utc': '2024-04-22T15:00:00+00:00',
#     'local': '2024-04-22T17:00:00+02:00'}},
#   {'id': 71,
#    'name': 'Biest Houtakker-Biestsestraat',
#    'locality': 'Biest Houtakker',
#    'timezone': 'Europe/Amsterdam',
#    'country': {'id': 135, 'code': 'NL', 'name': 'Netherlands'},
#    'owner': {'id': 4, 'name': 'Unknown Governmental Organization'},
#    'provider': {'id': 70, 'name': 'EEA'},
#    'isMobile': False,
#    'isMonitor': True,
#    'instruments': [{'id': 2, 'name': 'Government Monitor'}],
#    'sensors': [{'id': 4139,
#      'name': 'o3 µg/m³',
#      'parameter': {'id': 3,
#       'name': 'o3',
#       'units': 'µg/m³',
#       'displayName': 'O₃ mass'}},
#     {'id': 4276107,
#      'name': 'no µg/m³',
#      'parameter': {'id': 19843,
#       'name': 'no',
#       'units': 'µg/m³',
#       'displayName': 'NO mass'}},
#     {'id': 109,
#      'name': 'no2 µg/m³',
#      'parameter': {'id': 5,
#       'name': 'no2',
#       'units': 'µg/m³',
#       'displayName': 'NO₂ mass'}},
#     {'id': 4610,
#      'name': 'pm25 µg/m³',
#      'parameter': {'id': 2,
#       'name': 'pm25',
#       'units': 'µg/m³',
#       'displayName': 'PM2.5'}},
#     {'id': 4196,
#      'name': 'pm10 µg/m³',
#      'parameter': {'id': 1,
#       'name': 'pm10',
#       'units': 'µg/m³',
#       'displayName': 'PM10'}}],
#    'coordinates': {'latitude': 51.51843999935553,
#     'longitude': 5.148450000227909},
#    'licenses': None,
#    'bounds': [5.148450000227909,
#     51.51843999935553,
#     5.148450000227909,
#     51.51843999935553],
#    'distance': None,
#    'datetimeFirst': {'utc': '2016-01-30T01:00:00+00:00',
#     'local': '2016-01-30T02:00:00+01:00'},
#    'datetimeLast': {'utc': '2024-04-22T15:00:00+00:00',
#     'local': '2024-04-22T17:00:00+02:00'}},
#   {'id': 76,
#    'name': 'De Zilk-Vogelaarsdreef',
#    'locality': 'De Zilk',
#    'timezone': 'Europe/Amsterdam',
#    'country': {'id': 135, 'code': 'NL', 'name': 'Netherlands'},
#    'owner': {'id': 4, 'name': 'Unknown Governmental Organization'},
#    'provider': {'id': 70, 'name': 'EEA'},
#    'isMobile': False,
#    'isMonitor': True,
#    'instruments': [{'id': 2, 'name': 'Government Monitor'}],
#    'sensors': [{'id': 4275734,
#      'name': 'no µg/m³',
#      'parameter': {'id': 19843,
#       'name': 'no',
#       'units': 'µg/m³',
#       'displayName': 'NO mass'}},
#     {'id': 115,
#      'name': 'pm25 µg/m³',
#      'parameter': {'id': 2,
#       'name': 'pm25',
#       'units': 'µg/m³',
#       'displayName': 'PM2.5'}},
#     {'id': 4155,
#      'name': 'no2 µg/m³',
#      'parameter': {'id': 5,
#       'name': 'no2',
#       'units': 'µg/m³',
#       'displayName': 'NO₂ mass'}},
#     {'id': 4150,
#      'name': 'so2 µg/m³',
#      'parameter': {'id': 6,
#       'name': 'so2',
#       'units': 'µg/m³',
#       'displayName': 'SO₂ mass'}},
#     {'id': 4152,
#      'name': 'o3 µg/m³',
#      'parameter': {'id': 3,
#       'name': 'o3',
#       'units': 'µg/m³',
#       'displayName': 'O₃ mass'}},
#     {'id': 4537,
#      'name': 'pm10 µg/m³',
#      'parameter': {'id': 1,
#       'name': 'pm10',
#       'units': 'µg/m³',
#       'displayName': 'PM10'}}],
#    'coordinates': {'latitude': 52.29655599928061,
#     'longitude': 4.51081699998525},
#    'licenses': None,
#    'bounds': [4.51081699998525,
#     52.29655599928061,
#     4.51081699998525,
#     52.29655599928061],
#    'distance': None,
#    'datetimeFirst': {'utc': '2016-01-30T01:00:00+00:00',
#     'local': '2016-01-30T02:00:00+01:00'},
#    'datetimeLast': {'utc': '2024-04-22T15:00:00+00:00',
#     'local': '2024-04-22T17:00:00+02:00'}},
#   {'id': 77,
#    'name': 'Hoek v. Holland-Berghaven',
#    'locality': 'HOEK VAN HOLLAND',
#    'timezone': 'Europe/Amsterdam',
#    'country': {'id': 135, 'code': 'NL', 'name': 'Netherlands'},
#    'owner': {'id': 4, 'name': 'Unknown Governmental Organization'},
#    'provider': {'id': 70, 'name': 'EEA'},
#    'isMobile': False,
#    'isMonitor': True,
#    'instruments': [{'id': 2, 'name': 'Government Monitor'}],
#    'sensors': [{'id': 4221,
#      'name': 'pm25 µg/m³',
#      'parameter': {'id': 2,
#       'name': 'pm25',
#       'units': 'µg/m³',
#       'displayName': 'PM2.5'}},
#     {'id': 4219,
#      'name': 'pm10 µg/m³',
#      'parameter': {'id': 1,
#       'name': 'pm10',
#       'units': 'µg/m³',
#       'displayName': 'PM10'}},
#     {'id': 4276124,
#      'name': 'no µg/m³',
#      'parameter': {'id': 19843,
#       'name': 'no',
#       'units': 'µg/m³',
#       'displayName': 'NO mass'}},
#     {'id': 4218,
#      'name': 'o3 µg/m³',
#      'parameter': {'id': 3,
#       'name': 'o3',
#       'units': 'µg/m³',
#       'displayName': 'O₃ mass'}},
#     {'id': 116,
#      'name': 'no2 µg/m³',
#      'parameter': {'id': 5,
#       'name': 'no2',
#       'units': 'µg/m³',
#       'displayName': 'NO₂ mass'}},
#     {'id': 1301476,
#      'name': 'so2 µg/m³',
#      'parameter': {'id': 6,
#       'name': 'so2',
#       'units': 'µg/m³',
#       'displayName': 'SO₂ mass'}}],
#    'coordinates': {'latitude': 51.97780299967654,
#     'longitude': 4.121944000373796},
#    'licenses': None,
#    'bounds': [4.121944000373796,
#     51.97780299967654,
#     4.121944000373796,
#     51.97780299967654],
#    'distance': None,
#    'datetimeFirst': {'utc': '2016-01-30T01:00:00+00:00',
#     'local': '2016-01-30T02:00:00+01:00'},
#    'datetimeLast': {'utc': '2024-04-22T15:00:00+00:00',
#     'local': '2024-04-22T17:00:00+02:00'}},
#   {'id': 79,
#    'name': 'Hilversum-J. Gerardtsweg',
#    'locality': None,
#    'timezone': 'Europe/Amsterdam',
#    'country': {'id': 135, 'code': 'NL', 'name': 'Netherlands'},
#    'owner': {'id': 4, 'name': 'Unknown Governmental Organization'},
#    'provider': {'id': 210, 'name': 'Netherlands'},
#    'isMobile': False,
#    'isMonitor': True,
#    'instruments': [{'id': 2, 'name': 'Government Monitor'}],
#    'sensors': [{'id': 4621,
#      'name': 'pm10 µg/m³',
#      'parameter': {'id': 1,
#       'name': 'pm10',
#       'units': 'µg/m³',
#       'displayName': 'PM10'}},
#     {'id': 118,
#      'name': 'pm25 µg/m³',
#      'parameter': {'id': 2,
#       'name': 'pm25',
#       'units': 'µg/m³',
#       'displayName': 'PM2.5'}},
#     {'id': 4608,
#      'name': 'no2 µg/m³',
#      'parameter': {'id': 5,
#       'name': 'no2',
#       'units': 'µg/m³',
#       'displayName': 'NO₂ mass'}}],
#    'coordinates': {'latitude': 52.23510000000001, 'longitude': 5.18155},
#    'licenses': None,
#    'bounds': [5.18155, 52.23510000000001, 5.18155, 52.23510000000001],
#    'distance': None,
#    'datetimeFirst': {'utc': '2016-01-30T01:00:00+00:00',
#     'local': '2016-01-30T02:00:00+01:00'},
#    'datetimeLast': {'utc': '2018-06-25T10:00:00+00:00',
#     'local': '2018-06-25T12:00:00+02:00'}},
#   {'id': 80,
#    'name': 'Amsterdam-Van Diemenstraat',
#    'locality': 'AMSTERDAM',
#    'timezone': 'Europe/Amsterdam',
#    'country': {'id': 135, 'code': 'NL', 'name': 'Netherlands'},
#    'owner': {'id': 4, 'name': 'Unknown Governmental Organization'},
#    'provider': {'id': 70, 'name': 'EEA'},
#    'isMobile': False,
#    'isMonitor': True,
#    'instruments': [{'id': 2, 'name': 'Government Monitor'}],
#    'sensors': [{'id': 164,
#      'name': 'co µg/m³',
#      'parameter': {'id': 4,
#       'name': 'co',
#       'units': 'µg/m³',
#       'displayName': 'CO mass'}},
#     {'id': 4275959,
#      'name': 'no µg/m³',
#      'parameter': {'id': 19843,
#       'name': 'no',
#       'units': 'µg/m³',
#       'displayName': 'NO mass'}},
#     {'id': 4186,
#      'name': 'o3 µg/m³',
#      'parameter': {'id': 3,
#       'name': 'o3',
#       'units': 'µg/m³',
#       'displayName': 'O₃ mass'}},
#     {'id': 4235,
#      'name': 'pm25 µg/m³',
#      'parameter': {'id': 2,
#       'name': 'pm25',
#       'units': 'µg/m³',
#       'displayName': 'PM2.5'}},
#     {'id': 4244,
#      'name': 'no2 µg/m³',
#      'parameter': {'id': 5,
#       'name': 'no2',
#       'units': 'µg/m³',
#       'displayName': 'NO₂ mass'}},
#     {'id': 119,
#      'name': 'pm10 µg/m³',
#      'parameter': {'id': 1,
#       'name': 'pm10',
#       'units': 'µg/m³',
#       'displayName': 'PM10'}}],
#    'coordinates': {'latitude': 52.38998299964, 'longitude': 4.88781099987638},
#    'licenses': None,
#    'bounds': [4.88781099987638,
#     52.38998299964,
#     4.88781099987638,
#     52.38998299964],
#    'distance': None,
#    'datetimeFirst': {'utc': '2016-01-30T01:00:00+00:00',
#     'local': '2016-01-30T02:00:00+01:00'},
#    'datetimeLast': {'utc': '2024-04-22T15:00:00+00:00',
#     'local': '2024-04-22T17:00:00+02:00'}},
#   {'id': 82,
#    'name': 'Haarlem-Schipholweg',
#    'locality': 'Haarlem',
#    'timezone': 'Europe/Amsterdam',
#    'country': {'id': 135, 'code': 'NL', 'name': 'Netherlands'},
#    'owner': {'id': 4, 'name': 'Unknown Governmental Organization'},
#    'provider': {'id': 70, 'name': 'EEA'},
#    'isMobile': False,
#    'isMonitor': True,
#    'instruments': [{'id': 2, 'name': 'Government Monitor'}],
#    'sensors': [{'id': 4585,
#      'name': 'no2 µg/m³',
#      'parameter': {'id': 5,
#       'name': 'no2',
#       'units': 'µg/m³',
#       'displayName': 'NO₂ mass'}},
#     {'id': 4561,
#      'name': 'o3 µg/m³',
#      'parameter': {'id': 3,
#       'name': 'o3',
#       'units': 'µg/m³',
#       'displayName': 'O₃ mass'}},
#     {'id': 4276054,
#      'name': 'no µg/m³',
#      'parameter': {'id': 19843,
#       'name': 'no',
#       'units': 'µg/m³',
#       'displayName': 'NO mass'}},
#     {'id': 121,
#      'name': 'pm10 µg/m³',
#      'parameter': {'id': 1,
#       'name': 'pm10',
#       'units': 'µg/m³',
#       'displayName': 'PM10'}}],
#    'coordinates': {'latitude': 52.37050799948144,
#     'longitude': 4.642319000180212},
#    'licenses': None,
#    'bounds': [4.642319000180212,
#     52.37050799948144,
#     4.642319000180212,
#     52.37050799948144],
#    'distance': None,
#    'datetimeFirst': {'utc': '2016-01-30T01:00:00+00:00',
#     'local': '2016-01-30T02:00:00+01:00'},
#    'datetimeLast': {'utc': '2024-04-22T15:00:00+00:00',
#     'local': '2024-04-22T17:00:00+02:00'}},
#   {'id': 85,
#    'name': 'Hellendoorn-Luttenbergerweg',
#    'locality': 'Hellendoorn',
#    'timezone': 'Europe/Amsterdam',
#    'country': {'id': 135, 'code': 'NL', 'name': 'Netherlands'},
#    'owner': {'id': 4, 'name': 'Unknown Governmental Organization'},
#    'provider': {'id': 70, 'name': 'EEA'},
#    'isMobile': False,
#    'isMonitor': True,
#    'instruments': [{'id': 2, 'name': 'Government Monitor'}],
#    'sensors': [{'id': 4275730,
#      'name': 'no µg/m³',
#      'parameter': {'id': 19843,
#       'name': 'no',
#       'units': 'µg/m³',
#       'displayName': 'NO mass'}},
#     {'id': 4411,
#      'name': 'no2 µg/m³',
#      'parameter': {'id': 5,
#       'name': 'no2',
#       'units': 'µg/m³',
#       'displayName': 'NO₂ mass'}},
#     {'id': 4413,
#      'name': 'o3 µg/m³',
#      'parameter': {'id': 3,
#       'name': 'o3',
#       'units': 'µg/m³',
#       'displayName': 'O₃ mass'}},
#     {'id': 132,
#      'name': 'pm10 µg/m³',
#      'parameter': {'id': 1,
#       'name': 'pm10',
#       'units': 'µg/m³',
#       'displayName': 'PM10'}}],
#    'coordinates': {'latitude': 52.388271999436746,
#     'longitude': 6.402932999609704},
#    'licenses': None,
#    'bounds': [6.402932999609704,
#     52.388271999436746,
#     6.402932999609704,
#     52.388271999436746],
#    'distance': None,
#    'datetimeFirst': {'utc': '2016-01-30T01:00:00+00:00',
#     'local': '2016-01-30T02:00:00+01:00'},
#    'datetimeLast': {'utc': '2024-04-22T15:00:00+00:00',
#     'local': '2024-04-22T17:00:00+02:00'}},
#   {'id': 93,
#    'name': 'Nijmegen-Graafseweg',
#    'locality': 'NIJMEGEN',
#    'timezone': 'Europe/Amsterdam',
#    'country': {'id': 135, 'code': 'NL', 'name': 'Netherlands'},
#    'owner': {'id': 4, 'name': 'Unknown Governmental Organization'},
#    'provider': {'id': 70, 'name': 'EEA'},
#    'isMobile': False,
#    'isMonitor': True,
#    'instruments': [{'id': 2, 'name': 'Government Monitor'}],
#    'sensors': [{'id': 4276167,
#      'name': 'no µg/m³',
#      'parameter': {'id': 19843,
#       'name': 'no',
#       'units': 'µg/m³',
#       'displayName': 'NO mass'}},
#     {'id': 4230,
#      'name': 'co µg/m³',
#      'parameter': {'id': 4,
#       'name': 'co',
#       'units': 'µg/m³',
#       'displayName': 'CO mass'}},
#     {'id': 151,
#      'name': 'no2 µg/m³',
#      'parameter': {'id': 5,
#       'name': 'no2',
#       'units': 'µg/m³',
#       'displayName': 'NO₂ mass'}},
#     {'id': 4224,
#      'name': 'pm10 µg/m³',
#      'parameter': {'id': 1,
#       'name': 'pm10',
#       'units': 'µg/m³',
#       'displayName': 'PM10'}},
#     {'id': 4212,
#      'name': 'pm25 µg/m³',
#      'parameter': {'id': 2,
#       'name': 'pm25',
#       'units': 'µg/m³',
#       'displayName': 'PM2.5'}}],
#    'coordinates': {'latitude': 51.84137199963026,
#     'longitude': 5.857776999815399},
#    'licenses': None,
#    'bounds': [5.857776999815399,
#     51.84137199963026,
#     5.857776999815399,
#     51.84137199963026],
#    'distance': None,
#    'datetimeFirst': {'utc': '2016-01-30T01:00:00+00:00',
#     'local': '2016-01-30T02:00:00+01:00'},
#    'datetimeLast': {'utc': '2024-04-22T15:00:00+00:00',
#     'local': '2024-04-22T17:00:00+02:00'}},
#   {'id': 95,
#    'name': 'Amsterdam-Vondelpark',
#    'locality': 'AMSTERDAM',
#    'timezone': 'Europe/Amsterdam',
#    'country': {'id': 135, 'code': 'NL', 'name': 'Netherlands'},
#    'owner': {'id': 4, 'name': 'Unknown Governmental Organization'},
#    'provider': {'id': 70, 'name': 'EEA'},
#    'isMobile': False,
#    'isMonitor': True,
#    'instruments': [{'id': 2, 'name': 'Government Monitor'}],
#    'sensors': [{'id': 4383,
#      'name': 'pm10 µg/m³',
#      'parameter': {'id': 1,
#       'name': 'pm10',
#       'units': 'µg/m³',
#       'displayName': 'PM10'}},
#     {'id': 4390,
#      'name': 'pm25 µg/m³',
#      'parameter': {'id': 2,
#       'name': 'pm25',
#       'units': 'µg/m³',
#       'displayName': 'PM2.5'}},
#     {'id': 4461,
#      'name': 'o3 µg/m³',
#      'parameter': {'id': 3,
#       'name': 'o3',
#       'units': 'µg/m³',
#       'displayName': 'O₃ mass'}},
#     {'id': 4275709,
#      'name': 'no µg/m³',
#      'parameter': {'id': 19843,
#       'name': 'no',
#       'units': 'µg/m³',
#       'displayName': 'NO mass'}},
#     {'id': 4364,
#      'name': 'no2 µg/m³',
#      'parameter': {'id': 5,
#       'name': 'no2',
#       'units': 'µg/m³',
#       'displayName': 'NO₂ mass'}},
#     {'id': 157,
#      'name': 'co µg/m³',
#      'parameter': {'id': 4,
#       'name': 'co',
#       'units': 'µg/m³',
#       'displayName': 'CO mass'}}],
#    'coordinates': {'latitude': 52.35971399946527,
#     'longitude': 4.866208000411839},
#    'licenses': None,
#    'bounds': [4.866208000411839,
#     52.35971399946527,
#     4.866208000411839,
#     52.35971399946527],
#    'distance': None,
#    'datetimeFirst': {'utc': '2016-01-30T01:00:00+00:00',
#     'local': '2016-01-30T02:00:00+01:00'},
#    'datetimeLast': {'utc': '2024-04-22T15:00:00+00:00',
#     'local': '2024-04-22T17:00:00+02:00'}},
#   {'id': 96,
#    'name': 'Wijk aan Zee-Burgemeester Rothestraat',
#    'locality': 'WIJK AAN ZEE',
#    'timezone': 'Europe/Amsterdam',
#    'country': {'id': 135, 'code': 'NL', 'name': 'Netherlands'},
#    'owner': {'id': 4, 'name': 'Unknown Governmental Organization'},
#    'provider': {'id': 70, 'name': 'EEA'},
#    'isMobile': False,
#    'isMonitor': True,
#    'instruments': [{'id': 2, 'name': 'Government Monitor'}],
#    'sensors': [{'id': 167,
#      'name': 'co µg/m³',
#      'parameter': {'id': 4,
#       'name': 'co',
#       'units': 'µg/m³',
#       'displayName': 'CO mass'}},
#     {'id': 158,
#      'name': 'so2 µg/m³',
#      'parameter': {'id': 6,
#       'name': 'so2',
#       'units': 'µg/m³',
#       'displayName': 'SO₂ mass'}},
#     {'id': 4290,
#      'name': 'pm10 µg/m³',
#      'parameter': {'id': 1,
#       'name': 'pm10',
#       'units': 'µg/m³',
#       'displayName': 'PM10'}},
#     {'id': 4280,
#      'name': 'no2 µg/m³',
#      'parameter': {'id': 5,
#       'name': 'no2',
#       'units': 'µg/m³',
#       'displayName': 'NO₂ mass'}},
#     {'id': 4367,
#      'name': 'pm25 µg/m³',
#      'parameter': {'id': 2,
#       'name': 'pm25',
#       'units': 'µg/m³',
#       'displayName': 'PM2.5'}},
#     {'id': 4275778,
#      'name': 'no µg/m³',
#      'parameter': {'id': 19843,
#       'name': 'no',
#       'units': 'µg/m³',
#       'displayName': 'NO mass'}}],
#    'coordinates': {'latitude': 52.49399199950157,
#     'longitude': 4.601986000379324},
#    'licenses': None,
#    'bounds': [4.601986000379324,
#     52.49399199950157,
#     4.601986000379324,
#     52.49399199950157],
#    'distance': None,
#    'datetimeFirst': {'utc': '2016-01-30T01:00:00+00:00',
#     'local': '2016-01-30T02:00:00+01:00'},
#    'datetimeLast': {'utc': '2024-04-22T15:00:00+00:00',
#     'local': '2024-04-22T17:00:00+02:00'}},
#   {'id': 97,
#    'name': 'IJmuiden-Kanaaldijk',
#    'locality': 'IJMUIDEN',
#    'timezone': 'Europe/Amsterdam',
#    'country': {'id': 135, 'code': 'NL', 'name': 'Netherlands'},
#    'owner': {'id': 4, 'name': 'Unknown Governmental Organization'},
#    'provider': {'id': 70, 'name': 'EEA'},
#    'isMobile': False,
#    'isMonitor': True,
#    'instruments': [{'id': 2, 'name': 'Government Monitor'}],
#    'sensors': [{'id': 4276088,
#      'name': 'no µg/m³',
#      'parameter': {'id': 19843,
#       'name': 'no',
#       'units': 'µg/m³',
#       'displayName': 'NO mass'}},
#     {'id': 159,
#      'name': 'so2 µg/m³',
#      'parameter': {'id': 6,
#       'name': 'so2',
#       'units': 'µg/m³',
#       'displayName': 'SO₂ mass'}},
#     {'id': 4541,
#      'name': 'pm25 µg/m³',
#      'parameter': {'id': 2,
#       'name': 'pm25',
#       'units': 'µg/m³',
#       'displayName': 'PM2.5'}},
#     {'id': 4570,
#      'name': 'no2 µg/m³',
#      'parameter': {'id': 5,
#       'name': 'no2',
#       'units': 'µg/m³',
#       'displayName': 'NO₂ mass'}},
#     {'id': 165,
#      'name': 'co µg/m³',
#      'parameter': {'id': 4,
#       'name': 'co',
#       'units': 'µg/m³',
#       'displayName': 'CO mass'}},
#     {'id': 4565,
#      'name': 'pm10 µg/m³',
#      'parameter': {'id': 1,
#       'name': 'pm10',
#       'units': 'µg/m³',
#       'displayName': 'PM10'}}],
#    'coordinates': {'latitude': 52.46303899955133,
#     'longitude': 4.60184200043928},
#    'licenses': None,
#    'bounds': [4.60184200043928,
#     52.46303899955133,
#     4.60184200043928,
#     52.46303899955133],
#    'distance': None,
#    'datetimeFirst': {'utc': '2016-01-30T01:00:00+00:00',
#     'local': '2016-01-30T02:00:00+01:00'},
#    'datetimeLast': {'utc': '2024-04-22T15:00:00+00:00',
#     'local': '2024-04-22T17:00:00+02:00'}},
#   {'id': 98,
#    'name': 'Amsterdam-Westerpark',
#    'locality': 'AMSTERDAM',
#    'timezone': 'Europe/Amsterdam',
#    'country': {'id': 135, 'code': 'NL', 'name': 'Netherlands'},
#    'owner': {'id': 4, 'name': 'Unknown Governmental Organization'},
#    'provider': {'id': 70, 'name': 'EEA'},
#    'isMobile': False,
#    'isMonitor': True,
#    'instruments': [{'id': 2, 'name': 'Government Monitor'}],
#    'sensors': [{'id': 4344,
#      'name': 'pm25 µg/m³',
#      'parameter': {'id': 2,
#       'name': 'pm25',
#       'units': 'µg/m³',
#       'displayName': 'PM2.5'}},
#     {'id': 4700,
#      'name': 'pm10 µg/m³',
#      'parameter': {'id': 1,
#       'name': 'pm10',
#       'units': 'µg/m³',
#       'displayName': 'PM10'}},
#     {'id': 160,
#      'name': 'so2 µg/m³',
#      'parameter': {'id': 6,
#       'name': 'so2',
#       'units': 'µg/m³',
#       'displayName': 'SO₂ mass'}}],
#    'coordinates': {'latitude': 52.393971999707986,
#     'longitude': 4.870156999790721},
#    'licenses': None,
#    'bounds': [4.870156999790721,
#     52.393971999707986,
#     4.870156999790721,
#     52.393971999707986],
#    'distance': None,
#    'datetimeFirst': {'utc': '2016-01-30T01:00:00+00:00',
#     'local': '2016-01-30T02:00:00+01:00'},
#    'datetimeLast': {'utc': '2024-04-22T15:00:00+00:00',
#     'local': '2024-04-22T17:00:00+02:00'}},
#   {'id': 100,
#    'name': 'Badhoevedorp-Sloterweg',
#    'locality': 'Badhoevedorp',
#    'timezone': 'Europe/Amsterdam',
#    'country': {'id': 135, 'code': 'NL', 'name': 'Netherlands'},
#    'owner': {'id': 4, 'name': 'Unknown Governmental Organization'},
#    'provider': {'id': 70, 'name': 'EEA'},
#    'isMobile': False,
#    'isMonitor': True,
#    'instruments': [{'id': 2, 'name': 'Government Monitor'}],
#    'sensors': [{'id': 162,
#      'name': 'co µg/m³',
#      'parameter': {'id': 4,
#       'name': 'co',
#       'units': 'µg/m³',
#       'displayName': 'CO mass'}},
#     {'id': 4147,
#      'name': 'pm25 µg/m³',
#      'parameter': {'id': 2,
#       'name': 'pm25',
#       'units': 'µg/m³',
#       'displayName': 'PM2.5'}},
#     {'id': 4237,
#      'name': 'no2 µg/m³',
#      'parameter': {'id': 5,
#       'name': 'no2',
#       'units': 'µg/m³',
#       'displayName': 'NO₂ mass'}},
#     {'id': 4231,
#      'name': 'pm10 µg/m³',
#      'parameter': {'id': 1,
#       'name': 'pm10',
#       'units': 'µg/m³',
#       'displayName': 'PM10'}},
#     {'id': 4275786,
#      'name': 'no µg/m³',
#      'parameter': {'id': 19843,
#       'name': 'no',
#       'units': 'µg/m³',
#       'displayName': 'NO mass'}}],
#    'coordinates': {'latitude': 52.33400299970228,
#     'longitude': 4.7740060003231},
#    'licenses': None,
#    'bounds': [4.7740060003231,
#     52.33400299970228,
#     4.7740060003231,
#     52.33400299970228],
#    'distance': None,
#    'datetimeFirst': {'utc': '2016-01-30T01:00:00+00:00',
#     'local': '2016-01-30T02:00:00+01:00'},
#    'datetimeLast': {'utc': '2024-04-22T15:00:00+00:00',
#     'local': '2024-04-22T17:00:00+02:00'}},
#   {'id': 101,
#    'name': 'Amsterdam-Hoogtij',
#    'locality': 'AMSTERDAM',
#    'timezone': 'Europe/Amsterdam',
#    'country': {'id': 135, 'code': 'NL', 'name': 'Netherlands'},
#    'owner': {'id': 4, 'name': 'Unknown Governmental Organization'},
#    'provider': {'id': 70, 'name': 'EEA'},
#    'isMobile': False,
#    'isMonitor': True,
#    'instruments': [{'id': 2, 'name': 'Government Monitor'}],
#    'sensors': [{'id': 4275834,
#      'name': 'no µg/m³',
#      'parameter': {'id': 19843,
#       'name': 'no',
#       'units': 'µg/m³',
#       'displayName': 'NO mass'}},
#     {'id': 163,
#      'name': 'so2 µg/m³',
#      'parameter': {'id': 6,
#       'name': 'so2',
#       'units': 'µg/m³',
#       'displayName': 'SO₂ mass'}},
#     {'id': 4187,
#      'name': 'no2 µg/m³',
#      'parameter': {'id': 5,
#       'name': 'no2',
#       'units': 'µg/m³',
#       'displayName': 'NO₂ mass'}},
#     {'id': 4687,
#      'name': 'pm25 µg/m³',
#      'parameter': {'id': 2,
#       'name': 'pm25',
#       'units': 'µg/m³',
#       'displayName': 'PM2.5'}},
#     {'id': 4112,
#      'name': 'pm10 µg/m³',
#      'parameter': {'id': 1,
#       'name': 'pm10',
#       'units': 'µg/m³',
#       'displayName': 'PM10'}}],
#    'coordinates': {'latitude': 52.42801699972565,
#     'longitude': 4.7734780002434976},
#    'licenses': None,
#    'bounds': [4.7734780002434976,
#     52.42801699972565,
#     4.7734780002434976,
#     52.42801699972565],
#    'distance': None,
#    'datetimeFirst': {'utc': '2016-01-30T01:00:00+00:00',
#     'local': '2016-01-30T02:00:00+01:00'},
#    'datetimeLast': {'utc': '2024-04-22T15:00:00+00:00',
#     'local': '2024-04-22T17:00:00+02:00'}},
#   {'id': 102,
#    'name': 'Amsterdam-Einsteinweg',
#    'locality': 'AMSTERDAM',
#    'timezone': 'Europe/Amsterdam',
#    'country': {'id': 135, 'code': 'NL', 'name': 'Netherlands'},
#    'owner': {'id': 4, 'name': 'Unknown Governmental Organization'},
#    'provider': {'id': 70, 'name': 'EEA'},
#    'isMobile': False,
#    'isMonitor': True,
#    'instruments': [{'id': 2, 'name': 'Government Monitor'}],
#    'sensors': [{'id': 4369,
#      'name': 'pm10 µg/m³',
#      'parameter': {'id': 1,
#       'name': 'pm10',
#       'units': 'µg/m³',
#       'displayName': 'PM10'}},
#     {'id': 4276086,
#      'name': 'no µg/m³',
#      'parameter': {'id': 19843,
#       'name': 'no',
#       'units': 'µg/m³',
#       'displayName': 'NO mass'}},
#     {'id': 4370,
#      'name': 'no2 µg/m³',
#      'parameter': {'id': 5,
#       'name': 'no2',
#       'units': 'µg/m³',
#       'displayName': 'NO₂ mass'}},
#     {'id': 4215,
#      'name': 'pm25 µg/m³',
#      'parameter': {'id': 2,
#       'name': 'pm25',
#       'units': 'µg/m³',
#       'displayName': 'PM2.5'}},
#     {'id': 166,
#      'name': 'co µg/m³',
#      'parameter': {'id': 4,
#       'name': 'co',
#       'units': 'µg/m³',
#       'displayName': 'CO mass'}}],
#    'coordinates': {'latitude': 52.38133099968318,
#     'longitude': 4.845232999687698},
#    'licenses': None,
#    'bounds': [4.845232999687698,
#     52.38133099968318,
#     4.845232999687698,
#     52.38133099968318],
#    'distance': None,
#    'datetimeFirst': {'utc': '2016-01-30T01:00:00+00:00',
#     'local': '2016-01-30T02:00:00+01:00'},
#    'datetimeLast': {'utc': '2024-04-22T15:00:00+00:00',
#     'local': '2024-04-22T17:00:00+02:00'}},
#   {'id': 241,
#    'name': 'Pernis-Soetemanweg',
#    'locality': None,
#    'timezone': 'Europe/Amsterdam',
#    'country': {'id': 135, 'code': 'NL', 'name': 'Netherlands'},
#    'owner': {'id': 4, 'name': 'Unknown Governmental Organization'},
#    'provider': {'id': 210, 'name': 'Netherlands'},
#    'isMobile': False,
#    'isMonitor': True,
#    'instruments': [{'id': 2, 'name': 'Government Monitor'}],
#    'sensors': [{'id': 406,
#      'name': 'pm10 µg/m³',
#      'parameter': {'id': 1,
#       'name': 'pm10',
#       'units': 'µg/m³',
#       'displayName': 'PM10'}},
#     {'id': 405,
#      'name': 'no2 µg/m³',
#      'parameter': {'id': 5,
#       'name': 'no2',
#       'units': 'µg/m³',
#       'displayName': 'NO₂ mass'}}],
#    'coordinates': {'latitude': 51.8879, 'longitude': 4.38881},
#    'licenses': None,
#    'bounds': [4.38881, 51.8879, 4.38881, 51.8879],
#    'distance': None,
#    'datetimeFirst': {'utc': '2016-01-30T01:00:00+00:00',
#     'local': '2016-01-30T02:00:00+01:00'},
#    'datetimeLast': {'utc': '2016-03-23T14:00:00+00:00',
#     'local': '2016-03-23T15:00:00+01:00'}},
#   {'id': 265,
#    'name': 'Botlek-Spoortunnel',
#    'locality': 'Botlek',
#    'timezone': 'Europe/Amsterdam',
#    'country': {'id': 135, 'code': 'NL', 'name': 'Netherlands'},
#    'owner': {'id': 4, 'name': 'Unknown Governmental Organization'},
#    'provider': {'id': 210, 'name': 'Netherlands'},
#    'isMobile': False,
#    'isMonitor': True,
#    'instruments': [{'id': 2, 'name': 'Government Monitor'}],
#    'sensors': [{'id': 447,
#      'name': 'pm25 µg/m³',
#      'parameter': {'id': 2,
#       'name': 'pm25',
#       'units': 'µg/m³',
#       'displayName': 'PM2.5'}},
#     {'id': 446,
#      'name': 'no2 µg/m³',
#      'parameter': {'id': 5,
#       'name': 'no2',
#       'units': 'µg/m³',
#       'displayName': 'NO₂ mass'}},
#     {'id': 448,
#      'name': 'pm10 µg/m³',
#      'parameter': {'id': 1,
#       'name': 'pm10',
#       'units': 'µg/m³',
#       'displayName': 'PM10'}},
#     {'id': 4276233,
#      'name': 'no µg/m³',
#      'parameter': {'id': 19843,
#       'name': 'no',
#       'units': 'µg/m³',
#       'displayName': 'NO mass'}}],
#    'coordinates': {'latitude': 51.8701, 'longitude': 4.31806},
#    'licenses': None,
#    'bounds': [4.31806, 51.8701, 4.31806, 51.8701],
#    'distance': None,
#    'datetimeFirst': {'utc': '2016-01-30T01:00:00+00:00',
#     'local': '2016-01-30T02:00:00+01:00'},
#    'datetimeLast': {'utc': '2024-04-22T14:00:00+00:00',
#     'local': '2024-04-22T16:00:00+02:00'}},
#   {'id': 2276,
#    'name': 'Biddinghuizen-Hoekwantweg',
#    'locality': None,
#    'timezone': 'Europe/Amsterdam',
#    'country': {'id': 135, 'code': 'NL', 'name': 'Netherlands'},
#    'owner': {'id': 4, 'name': 'Unknown Governmental Organization'},
#    'provider': {'id': 210, 'name': 'Netherlands'},
#    'isMobile': False,
#    'isMonitor': True,
#    'instruments': [{'id': 2, 'name': 'Government Monitor'}],
#    'sensors': [{'id': 4357,
#      'name': 'o3 µg/m³',
#      'parameter': {'id': 3,
#       'name': 'o3',
#       'units': 'µg/m³',
#       'displayName': 'O₃ mass'}},
#     {'id': 4356,
#      'name': 'no2 µg/m³',
#      'parameter': {'id': 5,
#       'name': 'no2',
#       'units': 'µg/m³',
#       'displayName': 'NO₂ mass'}},
#     {'id': 4105,
#      'name': 'pm10 µg/m³',
#      'parameter': {'id': 1,
#       'name': 'pm10',
#       'units': 'µg/m³',
#       'displayName': 'PM10'}}],
#    'coordinates': {'latitude': 52.4487, 'longitude': 5.61921},
#    'licenses': None,
#    'bounds': [5.61921, 52.4487, 5.61921, 52.4487],
#    'distance': None,
#    'datetimeFirst': {'utc': '2016-01-30T01:00:00+00:00',
#     'local': '2016-01-30T02:00:00+01:00'},
#    'datetimeLast': {'utc': '2017-05-04T13:00:00+00:00',
#     'local': '2017-05-04T15:00:00+02:00'}},
#   {'id': 2278,
#    'name': 'Biddinghuizen-Kuilweg',
#    'locality': 'Biddinghuizen',
#    'timezone': 'Europe/Amsterdam',
#    'country': {'id': 135, 'code': 'NL', 'name': 'Netherlands'},
#    'owner': {'id': 4, 'name': 'Unknown Governmental Organization'},
#    'provider': {'id': 70, 'name': 'EEA'},
#    'isMobile': False,
#    'isMonitor': True,
#    'instruments': [{'id': 2, 'name': 'Government Monitor'}],
#    'sensors': [{'id': 4107,
#      'name': 'no2 µg/m³',
#      'parameter': {'id': 5,
#       'name': 'no2',
#       'units': 'µg/m³',
#       'displayName': 'NO₂ mass'}},
#     {'id': 4111,
#      'name': 'pm10 µg/m³',
#      'parameter': {'id': 1,
#       'name': 'pm10',
#       'units': 'µg/m³',
#       'displayName': 'PM10'}},
#     {'id': 4109,
#      'name': 'o3 µg/m³',
#      'parameter': {'id': 3,
#       'name': 'o3',
#       'units': 'µg/m³',
#       'displayName': 'O₃ mass'}},
#     {'id': 4276125,
#      'name': 'no µg/m³',
#      'parameter': {'id': 19843,
#       'name': 'no',
#       'units': 'µg/m³',
#       'displayName': 'NO mass'}}],
#    'coordinates': {'latitude': 52.42321399969354,
#     'longitude': 5.593378000230877},
#    'licenses': None,
#    'bounds': [5.593378000230877,
#     52.42321399969354,
#     5.593378000230877,
#     52.42321399969354],
#    'distance': None,
#    'datetimeFirst': {'utc': '2016-01-30T01:00:00+00:00',
#     'local': '2016-01-30T02:00:00+01:00'},
#    'datetimeLast': {'utc': '2024-04-22T15:00:00+00:00',
#     'local': '2024-04-22T17:00:00+02:00'}},
#   {'id': 2279,
#    'name': 'Utrecht-Constant Erzeijstraat',
#    'locality': 'Utrecht',
#    'timezone': 'Europe/Amsterdam',
#    'country': {'id': 135, 'code': 'NL', 'name': 'Netherlands'},
#    'owner': {'id': 4, 'name': 'Unknown Governmental Organization'},
#    'provider': {'id': 70, 'name': 'EEA'},
#    'isMobile': False,
#    'isMonitor': True,
#    'instruments': [{'id': 2, 'name': 'Government Monitor'}],
#    'sensors': [{'id': 4276017,
#      'name': 'no µg/m³',
#      'parameter': {'id': 19843,
#       'name': 'no',
#       'units': 'µg/m³',
#       'displayName': 'NO mass'}},
#     {'id': 4328,
#      'name': 'no2 µg/m³',
#      'parameter': {'id': 5,
#       'name': 'no2',
#       'units': 'µg/m³',
#       'displayName': 'NO₂ mass'}},
#     {'id': 4108,
#      'name': 'o3 µg/m³',
#      'parameter': {'id': 3,
#       'name': 'o3',
#       'units': 'µg/m³',
#       'displayName': 'O₃ mass'}},
#     {'id': 4110,
#      'name': 'pm10 µg/m³',
#      'parameter': {'id': 1,
#       'name': 'pm10',
#       'units': 'µg/m³',
#       'displayName': 'PM10'}}],
#    'coordinates': {'latitude': 52.06774799954149,
#     'longitude': 5.120506999610195},
#    'licenses': None,
#    'bounds': [5.120506999610195,
#     52.06774799954149,
#     5.120506999610195,
#     52.06774799954149],
#    'distance': None,
#    'datetimeFirst': {'utc': '2016-01-30T01:00:00+00:00',
#     'local': '2016-01-30T02:00:00+01:00'},
#    'datetimeLast': {'utc': '2024-04-22T15:00:00+00:00',
#     'local': '2024-04-22T17:00:00+02:00'}},
#   {'id': 2280,
#    'name': 'Utrecht-Griftpark',
#    'locality': 'UTRECHT',
#    'timezone': 'Europe/Amsterdam',
#    'country': {'id': 135, 'code': 'NL', 'name': 'Netherlands'},
#    'owner': {'id': 4, 'name': 'Unknown Governmental Organization'},
#    'provider': {'id': 70, 'name': 'EEA'},
#    'isMobile': False,
#    'isMonitor': True,
#    'instruments': [{'id': 2, 'name': 'Government Monitor'}],
#    'sensors': [{'id': 4116,
#      'name': 'pm25 µg/m³',
#      'parameter': {'id': 2,
#       'name': 'pm25',
#       'units': 'µg/m³',
#       'displayName': 'PM2.5'}},
#     {'id': 4276134,
#      'name': 'no µg/m³',
#      'parameter': {'id': 19843,
#       'name': 'no',
#       'units': 'µg/m³',
#       'displayName': 'NO mass'}},
#     {'id': 4115,
#      'name': 'o3 µg/m³',
#      'parameter': {'id': 3,
#       'name': 'o3',
#       'units': 'µg/m³',
#       'displayName': 'O₃ mass'}},
#     {'id': 4113,
#      'name': 'no2 µg/m³',
#      'parameter': {'id': 5,
#       'name': 'no2',
#       'units': 'µg/m³',
#       'displayName': 'NO₂ mass'}}],
#    'coordinates': {'latitude': 52.10130799970867,
#     'longitude': 5.1281830004067395},
#    'licenses': None,
#    'bounds': [5.1281830004067395,
#     52.10130799970867,
#     5.1281830004067395,
#     52.10130799970867],
#    'distance': None,
#    'datetimeFirst': {'utc': '2016-01-30T01:00:00+00:00',
#     'local': '2016-01-30T02:00:00+01:00'},
#    'datetimeLast': {'utc': '2024-04-22T15:00:00+00:00',
#     'local': '2024-04-22T17:00:00+02:00'}},
#   {'id': 2281,
#    'name': 'Breukelen-Snelweg',
#    'locality': 'Breukelen',
#    'timezone': 'Europe/Amsterdam',
#    'country': {'id': 135, 'code': 'NL', 'name': 'Netherlands'},
#    'owner': {'id': 4, 'name': 'Unknown Governmental Organization'},
#    'provider': {'id': 70, 'name': 'EEA'},
#    'isMobile': False,
#    'isMonitor': True,
#    'instruments': [{'id': 2, 'name': 'Government Monitor'}],
#    'sensors': [{'id': 4121,
#      'name': 'o3 µg/m³',
#      'parameter': {'id': 3,
#       'name': 'o3',
#       'units': 'µg/m³',
#       'displayName': 'O₃ mass'}},
#     {'id': 4120,
#      'name': 'pm10 µg/m³',
#      'parameter': {'id': 1,
#       'name': 'pm10',
#       'units': 'µg/m³',
#       'displayName': 'PM10'}},
#     {'id': 4119,
#      'name': 'pm25 µg/m³',
#      'parameter': {'id': 2,
#       'name': 'pm25',
#       'units': 'µg/m³',
#       'displayName': 'PM2.5'}},
#     {'id': 4123,
#      'name': 'no2 µg/m³',
#      'parameter': {'id': 5,
#       'name': 'no2',
#       'units': 'µg/m³',
#       'displayName': 'NO₂ mass'}},
#     {'id': 4276070,
#      'name': 'no µg/m³',
#      'parameter': {'id': 19843,
#       'name': 'no',
#       'units': 'µg/m³',
#       'displayName': 'NO mass'}}],
#    'coordinates': {'latitude': 52.20152999970324,
#     'longitude': 4.987443999640966},
#    'licenses': None,
#    'bounds': [4.987443999640966,
#     52.20152999970324,
#     4.987443999640966,
#     52.20152999970324],
#    'distance': None,
#    'datetimeFirst': {'utc': '2016-01-30T01:00:00+00:00',
#     'local': '2016-01-30T02:00:00+01:00'},
#    'datetimeLast': {'utc': '2024-04-22T15:00:00+00:00',
#     'local': '2024-04-22T17:00:00+02:00'}},
#   {'id': 2283,
#    'name': 'Velsen-Staalstraat',
#    'locality': 'VELSEN',
#    'timezone': 'Europe/Amsterdam',
#    'country': {'id': 135, 'code': 'NL', 'name': 'Netherlands'},
#    'owner': {'id': 4, 'name': 'Unknown Governmental Organization'},
#    'provider': {'id': 70, 'name': 'EEA'},
#    'isMobile': False,
#    'isMonitor': True,
#    'instruments': [{'id': 2, 'name': 'Government Monitor'}],
#    'sensors': [{'id': 4378,
#      'name': 'pm25 µg/m³',
#      'parameter': {'id': 2,
#       'name': 'pm25',
#       'units': 'µg/m³',
#       'displayName': 'PM2.5'}},
#     {'id': 4124,
#      'name': 'pm10 µg/m³',
#      'parameter': {'id': 1,
#       'name': 'pm10',
#       'units': 'µg/m³',
#       'displayName': 'PM10'}}],
#    'coordinates': {'latitude': 52.47439999962086,
#     'longitude': 4.628800000144586},
#    'licenses': None,
#    'bounds': [4.628800000144586,
#     52.47439999962086,
#     4.628800000144586,
#     52.47439999962086],
#    'distance': None,
#    'datetimeFirst': {'utc': '2016-01-30T01:00:00+00:00',
#     'local': '2016-01-30T02:00:00+01:00'},
#    'datetimeLast': {'utc': '2024-04-22T15:00:00+00:00',
#     'local': '2024-04-22T17:00:00+02:00'}},
#   {'id': 2288,
#    'name': 'Breda-Tilburgseweg',
#    'locality': 'BREDA',
#    'timezone': 'Europe/Amsterdam',
#    'country': {'id': 135, 'code': 'NL', 'name': 'Netherlands'},
#    'owner': {'id': 4, 'name': 'Unknown Governmental Organization'},
#    'provider': {'id': 70, 'name': 'EEA'},
#    'isMobile': False,
#    'isMonitor': True,
#    'instruments': [{'id': 2, 'name': 'Government Monitor'}],
#    'sensors': [{'id': 4132,
#      'name': 'pm25 µg/m³',
#      'parameter': {'id': 2,
#       'name': 'pm25',
#       'units': 'µg/m³',
#       'displayName': 'PM2.5'}},
#     {'id': 4135,
#      'name': 'no2 µg/m³',
#      'parameter': {'id': 5,
#       'name': 'no2',
#       'units': 'µg/m³',
#       'displayName': 'NO₂ mass'}},
#     {'id': 4276150,
#      'name': 'no µg/m³',
#      'parameter': {'id': 19843,
#       'name': 'no',
#       'units': 'µg/m³',
#       'displayName': 'NO mass'}},
#     {'id': 4133,
#      'name': 'pm10 µg/m³',
#      'parameter': {'id': 1,
#       'name': 'pm10',
#       'units': 'µg/m³',
#       'displayName': 'PM10'}}],
#    'coordinates': {'latitude': 51.593532999232885,
#     'longitude': 4.82494400012522},
#    'licenses': None,
#    'bounds': [4.82494400012522,
#     51.593532999232885,
#     4.82494400012522,
#     51.593532999232885],
#    'distance': None,
#    'datetimeFirst': {'utc': '2016-01-30T01:00:00+00:00',
# ...
#    'distance': None,
#    'datetimeFirst': {'utc': '2023-07-15T13:00:00+00:00',
#     'local': '2023-07-15T15:00:00+02:00'},
#    'datetimeLast': {'utc': '2024-04-22T16:00:00+00:00',
#     'local': '2024-04-22T18:00:00+02:00'}},
#   {'id': 1313460,
#    'name': 'Wierden',
#    'locality': None,
#    'timezone': 'Europe/Amsterdam',
#    'country': {'id': 135, 'code': 'NL', 'name': 'Netherlands'},
#    'owner': {'id': 4, 'name': 'Unknown Governmental Organization'},
#    'provider': {'id': 66, 'name': 'AirGradient'},
#    'isMobile': False,
#    'isMonitor': False,
#    'instruments': [{'id': 7, 'name': 'AirGradient Sensor'},
#     {'id': 1, 'name': 'N/A'}],
#    'sensors': [{'id': 7972300,
#      'name': 'relativehumidity %',
#      'parameter': {'id': 98,
#       'name': 'relativehumidity',
#       'units': '%',
#       'displayName': 'RH'}},
#     {'id': 7972299,
#      'name': 'um003 particles/cm³',
#      'parameter': {'id': 125,
#       'name': 'um003',
#       'units': 'particles/cm³',
#       'displayName': 'PM0.3 count'}},
#     {'id': 6606151,
#      'name': 'pm25 µg/m³',
#      'parameter': {'id': 2,
#       'name': 'pm25',
#       'units': 'µg/m³',
#       'displayName': 'PM2.5'}},
#     {'id': 6606149,
#      'name': 'temperature c',
#      'parameter': {'id': 100,
#       'name': 'temperature',
#       'units': 'c',
#       'displayName': 'T'}},
#     {'id': 7971288,
#      'name': 'pm1 µg/m³',
#      'parameter': {'id': 19,
#       'name': 'pm1',
#       'units': 'µg/m³',
#       'displayName': 'PM1'}},
#     {'id': 7978612,
#      'name': 'pm1 µg/m³',
#      'parameter': {'id': 19,
#       'name': 'pm1',
#       'units': 'µg/m³',
#       'displayName': 'PM1'}},
#     {'id': 7971022,
#      'name': 'pm10 µg/m³',
#      'parameter': {'id': 1,
#       'name': 'pm10',
#       'units': 'µg/m³',
#       'displayName': 'PM10'}},
#     {'id': 7978617,
#      'name': 'pm10 µg/m³',
#      'parameter': {'id': 1,
#       'name': 'pm10',
#       'units': 'µg/m³',
#       'displayName': 'PM10'}}],
#    'coordinates': {'latitude': 52.35917, 'longitude': 6.59306},
#    'licenses': None,
#    'bounds': [6.59306, 52.35917, 6.59306, 52.35917],
#    'distance': None,
#    'datetimeFirst': {'utc': '2023-07-24T15:00:00+00:00',
#     'local': '2023-07-24T17:00:00+02:00'},
#    'datetimeLast': {'utc': '2024-04-22T16:00:00+00:00',
#     'local': '2024-04-22T18:00:00+02:00'}},
#   {'id': 1391684,
#    'name': 'Dongen',
#    'locality': None,
#    'timezone': 'Europe/Amsterdam',
#    'country': {'id': 135, 'code': 'NL', 'name': 'Netherlands'},
#    'owner': {'id': 4, 'name': 'Unknown Governmental Organization'},
#    'provider': {'id': 66, 'name': 'AirGradient'},
#    'isMobile': False,
#    'isMonitor': False,
#    'instruments': [{'id': 7, 'name': 'AirGradient Sensor'},
#     {'id': 1, 'name': 'N/A'}],
#    'sensors': [{'id': 7971077,
#      'name': 'pm1 µg/m³',
#      'parameter': {'id': 19,
#       'name': 'pm1',
#       'units': 'µg/m³',
#       'displayName': 'PM1'}},
#     {'id': 7971119,
#      'name': 'pm10 µg/m³',
#      'parameter': {'id': 1,
#       'name': 'pm10',
#       'units': 'µg/m³',
#       'displayName': 'PM10'}},
#     {'id': 7979218,
#      'name': 'pm10 µg/m³',
#      'parameter': {'id': 1,
#       'name': 'pm10',
#       'units': 'µg/m³',
#       'displayName': 'PM10'}},
#     {'id': 7973184,
#      'name': 'relativehumidity %',
#      'parameter': {'id': 98,
#       'name': 'relativehumidity',
#       'units': '%',
#       'displayName': 'RH'}},
#     {'id': 6699572,
#      'name': 'temperature c',
#      'parameter': {'id': 100,
#       'name': 'temperature',
#       'units': 'c',
#       'displayName': 'T'}},
#     {'id': 7973158,
#      'name': 'um003 particles/cm³',
#      'parameter': {'id': 125,
#       'name': 'um003',
#       'units': 'particles/cm³',
#       'displayName': 'PM0.3 count'}},
#     {'id': 6699571,
#      'name': 'pm25 µg/m³',
#      'parameter': {'id': 2,
#       'name': 'pm25',
#       'units': 'µg/m³',
#       'displayName': 'PM2.5'}},
#     {'id': 7979223,
#      'name': 'pm1 µg/m³',
#      'parameter': {'id': 19,
#       'name': 'pm1',
#       'units': 'µg/m³',
#       'displayName': 'PM1'}}],
#    'coordinates': {'latitude': 51.636622, 'longitude': 4.931691},
#    'licenses': None,
#    'bounds': [4.931691, 51.636622, 4.931691, 51.636622],
#    'distance': None,
#    'datetimeFirst': {'utc': '2023-08-06T19:00:00+00:00',
#     'local': '2023-08-06T21:00:00+02:00'},
#    'datetimeLast': {'utc': '2024-04-22T16:00:00+00:00',
#     'local': '2024-04-22T18:00:00+02:00'}},
#   {'id': 1641178,
#    'name': 'Roden',
#    'locality': None,
#    'timezone': 'Europe/Amsterdam',
#    'country': {'id': 135, 'code': 'NL', 'name': 'Netherlands'},
#    'owner': {'id': 4, 'name': 'Unknown Governmental Organization'},
#    'provider': {'id': 66, 'name': 'AirGradient'},
#    'isMobile': False,
#    'isMonitor': False,
#    'instruments': [{'id': 7, 'name': 'AirGradient Sensor'}],
#    'sensors': [{'id': 7075985,
#      'name': 'pm25 µg/m³',
#      'parameter': {'id': 2,
#       'name': 'pm25',
#       'units': 'µg/m³',
#       'displayName': 'PM2.5'}},
#     {'id': 7075986,
#      'name': 'temperature c',
#      'parameter': {'id': 100,
#       'name': 'temperature',
#       'units': 'c',
#       'displayName': 'T'}},
#     {'id': 7972620,
#      'name': 'relativehumidity %',
#      'parameter': {'id': 98,
#       'name': 'relativehumidity',
#       'units': '%',
#       'displayName': 'RH'}}],
#    'coordinates': {'latitude': 53.146079, 'longitude': 6.41981},
#    'licenses': None,
#    'bounds': [6.41981, 53.146079, 6.41981, 53.146079],
#    'distance': None,
#    'datetimeFirst': {'utc': '2023-09-30T08:00:00+00:00',
#     'local': '2023-09-30T10:00:00+02:00'},
#    'datetimeLast': {'utc': '2024-04-22T16:00:00+00:00',
#     'local': '2024-04-22T18:00:00+02:00'}},
#   {'id': 1727877,
#    'name': 'Utrecht NLH',
#    'locality': None,
#    'timezone': 'Europe/Amsterdam',
#    'country': {'id': 135, 'code': 'NL', 'name': 'Netherlands'},
#    'owner': {'id': 4, 'name': 'Unknown Governmental Organization'},
#    'provider': {'id': 66, 'name': 'AirGradient'},
#    'isMobile': False,
#    'isMonitor': False,
#    'instruments': [{'id': 7, 'name': 'AirGradient Sensor'}],
#    'sensors': [{'id': 8918059,
#      'name': 'pm1 µg/m³',
#      'parameter': {'id': 19,
#       'name': 'pm1',
#       'units': 'µg/m³',
#       'displayName': 'PM1'}},
#     {'id': 8918054,
#      'name': 'relativehumidity %',
#      'parameter': {'id': 98,
#       'name': 'relativehumidity',
#       'units': '%',
#       'displayName': 'RH'}},
#     {'id': 8918061,
#      'name': 'um003 particles/cm³',
#      'parameter': {'id': 125,
#       'name': 'um003',
#       'units': 'particles/cm³',
#       'displayName': 'PM0.3 count'}},
#     {'id': 8918060,
#      'name': 'pm10 µg/m³',
#      'parameter': {'id': 1,
#       'name': 'pm10',
#       'units': 'µg/m³',
#       'displayName': 'PM10'}},
#     {'id': 7235524,
#      'name': 'temperature c',
#      'parameter': {'id': 100,
#       'name': 'temperature',
#       'units': 'c',
#       'displayName': 'T'}},
#     {'id': 7235525,
#      'name': 'pm25 µg/m³',
#      'parameter': {'id': 2,
#       'name': 'pm25',
#       'units': 'µg/m³',
#       'displayName': 'PM2.5'}}],
#    'coordinates': {'latitude': 52.09475147857455,
#     'longitude': 5.13453641455347},
#    'licenses': None,
#    'bounds': [5.13453641455347,
#     52.09475147857455,
#     5.13453641455347,
#     52.09475147857455],
#    'distance': None,
#    'datetimeFirst': {'utc': '2023-10-19T17:00:00+00:00',
#     'local': '2023-10-19T19:00:00+02:00'},
#    'datetimeLast': {'utc': '2024-04-22T16:00:00+00:00',
#     'local': '2024-04-22T18:00:00+02:00'}},
#   {'id': 1930621,
#    'name': 'Loenen',
#    'locality': None,
#    'timezone': 'Europe/Amsterdam',
#    'country': {'id': 135, 'code': 'NL', 'name': 'Netherlands'},
#    'owner': {'id': 12, 'name': 'AirGradient'},
#    'provider': {'id': 66, 'name': 'AirGradient'},
#    'isMobile': False,
#    'isMonitor': False,
#    'instruments': [{'id': 7, 'name': 'AirGradient Sensor'},
#     {'id': 7, 'name': 'AirGradient Sensor'}],
#    'sensors': [{'id': 7970884,
#      'name': 'pm1 µg/m³',
#      'parameter': {'id': 19,
#       'name': 'pm1',
#       'units': 'µg/m³',
#       'displayName': 'PM1'}},
#     {'id': 7505531,
#      'name': 'temperature c',
#      'parameter': {'id': 100,
#       'name': 'temperature',
#       'units': 'c',
#       'displayName': 'T'}},
#     {'id': 7505532,
#      'name': 'pm25 µg/m³',
#      'parameter': {'id': 2,
#       'name': 'pm25',
#       'units': 'µg/m³',
#       'displayName': 'PM2.5'}},
#     {'id': 7971259,
#      'name': 'pm10 µg/m³',
#      'parameter': {'id': 1,
#       'name': 'pm10',
#       'units': 'µg/m³',
#       'displayName': 'PM10'}},
#     {'id': 7978108,
#      'name': 'pm10 µg/m³',
#      'parameter': {'id': 1,
#       'name': 'pm10',
#       'units': 'µg/m³',
#       'displayName': 'PM10'}},
#     {'id': 7971376,
#      'name': 'um003 particles/cm³',
#      'parameter': {'id': 125,
#       'name': 'um003',
#       'units': 'particles/cm³',
#       'displayName': 'PM0.3 count'}},
#     {'id': 7971407,
#      'name': 'relativehumidity %',
#      'parameter': {'id': 98,
#       'name': 'relativehumidity',
#       'units': '%',
#       'displayName': 'RH'}},
#     {'id': 7978110,
#      'name': 'pm1 µg/m³',
#      'parameter': {'id': 19,
#       'name': 'pm1',
#       'units': 'µg/m³',
#       'displayName': 'PM1'}}],
#    'coordinates': {'latitude': 52.11278152063782,
#     'longitude': 6.021009600684539},
#    'licenses': None,
#    'bounds': [6.021009600684539,
#     52.11278152063782,
#     6.021009600684539,
#     52.11278152063782],
#    'distance': None,
#    'datetimeFirst': {'utc': '2023-12-07T16:00:00+00:00',
#     'local': '2023-12-07T17:00:00+01:00'},
#    'datetimeLast': {'utc': '2024-04-22T16:00:00+00:00',
#     'local': '2024-04-22T18:00:00+02:00'}},
#   {'id': 1996803,
#    'name': 'Beilen',
#    'locality': None,
#    'timezone': 'Europe/Amsterdam',
#    'country': {'id': 135, 'code': 'NL', 'name': 'Netherlands'},
#    'owner': {'id': 12, 'name': 'AirGradient'},
#    'provider': {'id': 66, 'name': 'AirGradient'},
#    'isMobile': False,
#    'isMonitor': False,
#    'instruments': [{'id': 7, 'name': 'AirGradient Sensor'},
#     {'id': 7, 'name': 'AirGradient Sensor'}],
#    'sensors': [{'id': 7971529,
#      'name': 'relativehumidity %',
#      'parameter': {'id': 98,
#       'name': 'relativehumidity',
#       'units': '%',
#       'displayName': 'RH'}},
#     {'id': 7978098,
#      'name': 'pm10 µg/m³',
#      'parameter': {'id': 1,
#       'name': 'pm10',
#       'units': 'µg/m³',
#       'displayName': 'PM10'}},
#     {'id': 7579593,
#      'name': 'temperature c',
#      'parameter': {'id': 100,
#       'name': 'temperature',
#       'units': 'c',
#       'displayName': 'T'}},
#     {'id': 7970925,
#      'name': 'pm10 µg/m³',
#      'parameter': {'id': 1,
#       'name': 'pm10',
#       'units': 'µg/m³',
#       'displayName': 'PM10'}},
#     {'id': 7978142,
#      'name': 'pm1 µg/m³',
#      'parameter': {'id': 19,
#       'name': 'pm1',
#       'units': 'µg/m³',
#       'displayName': 'PM1'}},
#     {'id': 7971183,
#      'name': 'pm1 µg/m³',
#      'parameter': {'id': 19,
#       'name': 'pm1',
#       'units': 'µg/m³',
#       'displayName': 'PM1'}},
#     {'id': 7579599,
#      'name': 'pm25 µg/m³',
#      'parameter': {'id': 2,
#       'name': 'pm25',
#       'units': 'µg/m³',
#       'displayName': 'PM2.5'}},
#     {'id': 7971539,
#      'name': 'um003 particles/cm³',
#      'parameter': {'id': 125,
#       'name': 'um003',
#       'units': 'particles/cm³',
#       'displayName': 'PM0.3 count'}}],
#    'coordinates': {'latitude': 52.847684, 'longitude': 6.517142},
#    'licenses': None,
#    'bounds': [6.517142, 52.847684, 6.517142, 52.847684],
#    'distance': None,
#    'datetimeFirst': {'utc': '2023-12-22T18:00:00+00:00',
#     'local': '2023-12-22T19:00:00+01:00'},
#    'datetimeLast': {'utc': '2024-04-22T16:00:00+00:00',
#     'local': '2024-04-22T18:00:00+02:00'}},
#   {'id': 2375983,
#    'name': 'Leiden - Stevenshof',
#    'locality': None,
#    'timezone': 'Europe/Amsterdam',
#    'country': {'id': 135, 'code': 'NL', 'name': 'Netherlands'},
#    'owner': {'id': 12, 'name': 'AirGradient'},
#    'provider': {'id': 66, 'name': 'AirGradient'},
#    'isMobile': False,
#    'isMonitor': False,
#    'instruments': [{'id': 7, 'name': 'AirGradient Sensor'},
#     {'id': 7, 'name': 'AirGradient Sensor'}],
#    'sensors': [{'id': 7971726,
#      'name': 'relativehumidity %',
#      'parameter': {'id': 98,
#       'name': 'relativehumidity',
#       'units': '%',
#       'displayName': 'RH'}},
#     {'id': 7979361,
#      'name': 'pm10 µg/m³',
#      'parameter': {'id': 1,
#       'name': 'pm10',
#       'units': 'µg/m³',
#       'displayName': 'PM10'}},
#     {'id': 7803067,
#      'name': 'pm25 µg/m³',
#      'parameter': {'id': 2,
#       'name': 'pm25',
#       'units': 'µg/m³',
#       'displayName': 'PM2.5'}},
#     {'id': 7971694,
#      'name': 'um003 particles/cm³',
#      'parameter': {'id': 125,
#       'name': 'um003',
#       'units': 'particles/cm³',
#       'displayName': 'PM0.3 count'}},
#     {'id': 7803058,
#      'name': 'temperature c',
#      'parameter': {'id': 100,
#       'name': 'temperature',
#       'units': 'c',
#       'displayName': 'T'}},
#     {'id': 7970854,
#      'name': 'pm1 µg/m³',
#      'parameter': {'id': 19,
#       'name': 'pm1',
#       'units': 'µg/m³',
#       'displayName': 'PM1'}},
#     {'id': 7979352,
#      'name': 'pm1 µg/m³',
#      'parameter': {'id': 19,
#       'name': 'pm1',
#       'units': 'µg/m³',
#       'displayName': 'PM1'}},
#     {'id': 7971146,
#      'name': 'pm10 µg/m³',
#      'parameter': {'id': 1,
#       'name': 'pm10',
#       'units': 'µg/m³',
#       'displayName': 'PM10'}}],
#    'coordinates': {'latitude': 52.1464619, 'longitude': 4.4488376},
#    'licenses': None,
#    'bounds': [4.4488376, 52.1464619, 4.4488376, 52.1464619],
#    'distance': None,
#    'datetimeFirst': {'utc': '2024-02-03T12:00:00+00:00',
#     'local': '2024-02-03T13:00:00+01:00'},
#    'datetimeLast': {'utc': '2024-04-22T16:00:00+00:00',
#     'local': '2024-04-22T18:00:00+02:00'}},
#   {'id': 2655997,
#    'name': 'Botlek-Oude Maasweg',
#    'locality': 'ROTTERDAM',
#    'timezone': 'Europe/Amsterdam',
#    'country': {'id': 135, 'code': 'NL', 'name': 'Netherlands'},
#    'owner': {'id': 4, 'name': 'Unknown Governmental Organization'},
#    'provider': {'id': 70, 'name': 'EEA'},
#    'isMobile': False,
#    'isMonitor': True,
#    'instruments': [{'id': 2, 'name': 'Government Monitor'}],
#    'sensors': [{'id': 8613166,
#      'name': 'so2 µg/m³',
#      'parameter': {'id': 6,
#       'name': 'so2',
#       'units': 'µg/m³',
#       'displayName': 'SO₂ mass'}}],
#    'coordinates': {'latitude': 51.888888999487634,
#     'longitude': 4.312499999586845},
#    'licenses': None,
#    'bounds': [4.312499999586845,
#     51.888888999487634,
#     4.312499999586845,
#     51.888888999487634],
#    'distance': None,
#    'datetimeFirst': {'utc': '2024-03-18T07:00:00+00:00',
#     'local': '2024-03-18T08:00:00+01:00'},
#    'datetimeLast': {'utc': '2024-04-22T15:00:00+00:00',
#     'local': '2024-04-22T17:00:00+02:00'}},
#   {'id': 2656046,
#    'name': 'Vlaardingen-Riouwlaan',
#    'locality': None,
#    'timezone': 'Europe/Amsterdam',
#    'country': {'id': 135, 'code': 'NL', 'name': 'Netherlands'},
#    'owner': {'id': 4, 'name': 'Unknown Governmental Organization'},
#    'provider': {'id': 70, 'name': 'EEA'},
#    'isMobile': False,
#    'isMonitor': True,
#    'instruments': [{'id': 2, 'name': 'Government Monitor'}],
#    'sensors': [{'id': 8613348,
#      'name': 'no2 µg/m³',
#      'parameter': {'id': 5,
#       'name': 'no2',
#       'units': 'µg/m³',
#       'displayName': 'NO₂ mass'}},
#     {'id': 8613127,
#      'name': 'pm10 µg/m³',
#      'parameter': {'id': 1,
#       'name': 'pm10',
#       'units': 'µg/m³',
#       'displayName': 'PM10'}},
#     {'id': 8613208,
#      'name': 'pm25 µg/m³',
#      'parameter': {'id': 2,
#       'name': 'pm25',
#       'units': 'µg/m³',
#       'displayName': 'PM2.5'}},
#     {'id': 8613191,
#      'name': 'o3 µg/m³',
#      'parameter': {'id': 3,
#       'name': 'o3',
#       'units': 'µg/m³',
#       'displayName': 'O₃ mass'}}],
#    'coordinates': {'latitude': 51.91488299927518,
#     'longitude': 4.329429999774322},
#    'licenses': None,
#    'bounds': [4.329429999774322,
#     51.91488299927518,
#     4.329429999774322,
#     51.91488299927518],
#    'distance': None,
#    'datetimeFirst': {'utc': '2024-03-18T07:00:00+00:00',
#     'local': '2024-03-18T08:00:00+01:00'},
#    'datetimeLast': {'utc': '2024-04-22T15:00:00+00:00',
#     'local': '2024-04-22T17:00:00+02:00'}}]}

# %%
data = result["results"]

# %%
df = pd.DataFrame(data)

# %%
df = df[df['locality']=='AMSTERDAM']

# %%
# number of location in amsterdam 
df['id'].nunique()
# Out:
# 13

# %%
print(df.head())
# Out:
#    locationId                    location parameter  value  \
# 0          80  Amsterdam-Van Diemenstraat      pm10   26.7
# 1          80  Amsterdam-Van Diemenstraat      pm10   24.5
# 2          80  Amsterdam-Van Diemenstraat      pm10   13.1
# 3          80  Amsterdam-Van Diemenstraat      pm10   12.3
# 4          80  Amsterdam-Van Diemenstraat      pm10   10.4
#
#                                                                          date  \
# 0  {'utc': '2024-04-22T08:00:00+00:00', 'local': '2024-04-22T10:00:00+02:00'}
# 1  {'utc': '2024-04-22T07:00:00+00:00', 'local': '2024-04-22T09:00:00+02:00'}
# 2  {'utc': '2024-04-22T06:00:00+00:00', 'local': '2024-04-22T08:00:00+02:00'}
# 3  {'utc': '2024-04-22T05:00:00+00:00', 'local': '2024-04-22T07:00:00+02:00'}
# 4  {'utc': '2024-04-22T04:00:00+00:00', 'local': '2024-04-22T06:00:00+02:00'}
#
#     unit                                                      coordinates  \
# 0  µg/m³  {'latitude': 52.389982999640004, 'longitude': 4.88781099987638}
# 1  µg/m³  {'latitude': 52.389982999640004, 'longitude': 4.88781099987638}
# 2  µg/m³  {'latitude': 52.389982999640004, 'longitude': 4.88781099987638}
# 3  µg/m³  {'latitude': 52.389982999640004, 'longitude': 4.88781099987638}
# 4  µg/m³  {'latitude': 52.389982999640004, 'longitude': 4.88781099987638}
#
#   country  city  isMobile isAnalysis                     entity  \
# 0      NL  None     False       None  Governmental Organization
# 1      NL  None     False       None  Governmental Organization
# 2      NL  None     False       None  Governmental Organization
# 3      NL  None     False       None  Governmental Organization
# 4      NL  None     False       None  Governmental Organization
#
#         sensorType
# 0  reference grade
# 1  reference grade
# 2  reference grade
# 3  reference grade
# 4  reference grade

# %%
column_names = df.columns
print(column_names)
# Out:
# Index(['id', 'name', 'locality', 'timezone', 'country', 'owner', 'provider',
#        'isMobile', 'isMonitor', 'instruments', 'sensors', 'coordinates',
#        'licenses', 'bounds', 'distance', 'datetimeFirst', 'datetimeLast'],
#       dtype='object')

# %%
#select
turncated_df = df[['name','locality','sensors']]

# %%
print(turncated_df)
# Out:
#                                     name   locality  \
# 12            Amsterdam-Van Diemenstraat  AMSTERDAM
# 16                  Amsterdam-Vondelpark  AMSTERDAM
# 19                  Amsterdam-Westerpark  AMSTERDAM
# 21                     Amsterdam-Hoogtij  AMSTERDAM
# 22                 Amsterdam-Einsteinweg  AMSTERDAM
# 35                 Amsterdam-Spaarnwoude  AMSTERDAM
# 39               Amsterdam-Haarlemmerweg  AMSTERDAM
# 41                 Amsterdam-Oude Schans  AMSTERDAM
# 52           Amsterdam-Nieuwendammerdijk  AMSTERDAM
# 53      Amsterdam-Kantershof (Zuid Oost)  AMSTERDAM
# 59         Amsterdam-Jan van Galenstraat  AMSTERDAM
# 62  Amsterdam-Sportpark Ookmeer (Osdorp)  AMSTERDAM
# 65             Amsterdam-Stadhouderskade  AMSTERDAM
#
#                                                                                                                                                                                                     sensors
# 12  [{'id': 4244, 'name': 'no2 µg/m³', 'parameter': {'id': 5, 'name': 'no2', 'units': 'µg/m³', 'displayName': 'NO₂ mass'}}, {'id': 4235, 'name': 'pm25 µg/m³', 'parameter': {'id': 2, 'name': 'pm25', 'u...
# 16  [{'id': 4275709, 'name': 'no µg/m³', 'parameter': {'id': 19843, 'name': 'no', 'units': 'µg/m³', 'displayName': 'NO mass'}}, {'id': 4461, 'name': 'o3 µg/m³', 'parameter': {'id': 3, 'name': 'o3', 'u...
# 19  [{'id': 4344, 'name': 'pm25 µg/m³', 'parameter': {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': 'PM2.5'}}, {'id': 160, 'name': 'so2 µg/m³', 'parameter': {'id': 6, 'name': 'so2', 'units...
# 21  [{'id': 4112, 'name': 'pm10 µg/m³', 'parameter': {'id': 1, 'name': 'pm10', 'units': 'µg/m³', 'displayName': 'PM10'}}, {'id': 163, 'name': 'so2 µg/m³', 'parameter': {'id': 6, 'name': 'so2', 'units'...
# 22  [{'id': 4215, 'name': 'pm25 µg/m³', 'parameter': {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': 'PM2.5'}}, {'id': 4369, 'name': 'pm10 µg/m³', 'parameter': {'id': 1, 'name': 'pm10', 'un...
# 35  [{'id': 5079263, 'name': 'no µg/m³', 'parameter': {'id': 19843, 'name': 'no', 'units': 'µg/m³', 'displayName': 'NO mass'}}, {'id': 5079262, 'name': 'no2 µg/m³', 'parameter': {'id': 5, 'name': 'no2...
# 39  [{'id': 7696649, 'name': 'no µg/m³', 'parameter': {'id': 19843, 'name': 'no', 'units': 'µg/m³', 'displayName': 'NO mass'}}, {'id': 4204, 'name': 'no2 µg/m³', 'parameter': {'id': 5, 'name': 'no2', ...
# 41  [{'id': 5079267, 'name': 'no µg/m³', 'parameter': {'id': 19843, 'name': 'no', 'units': 'µg/m³', 'displayName': 'NO mass'}}, {'id': 5079266, 'name': 'no2 µg/m³', 'parameter': {'id': 5, 'name': 'no2...
# 52  [{'id': 4310, 'name': 'o3 µg/m³', 'parameter': {'id': 3, 'name': 'o3', 'units': 'µg/m³', 'displayName': 'O₃ mass'}}, {'id': 4314, 'name': 'no2 µg/m³', 'parameter': {'id': 5, 'name': 'no2', 'units'...
# 53  [{'id': 4323, 'name': 'no2 µg/m³', 'parameter': {'id': 5, 'name': 'no2', 'units': 'µg/m³', 'displayName': 'NO₂ mass'}}, {'id': 4276237, 'name': 'no µg/m³', 'parameter': {'id': 19843, 'name': 'no',...
# 59  [{'id': 4358, 'name': 'pm10 µg/m³', 'parameter': {'id': 1, 'name': 'pm10', 'units': 'µg/m³', 'displayName': 'PM10'}}, {'id': 4459, 'name': 'no2 µg/m³', 'parameter': {'id': 5, 'name': 'no2', 'units...
# 62  [{'id': 4275884, 'name': 'no µg/m³', 'parameter': {'id': 19843, 'name': 'no', 'units': 'µg/m³', 'displayName': 'NO mass'}}, {'id': 4406, 'name': 'no2 µg/m³', 'parameter': {'id': 5, 'name': 'no2', ...
# 65  [{'id': 4504, 'name': 'pm10 µg/m³', 'parameter': {'id': 1, 'name': 'pm10', 'units': 'µg/m³', 'displayName': 'PM10'}}, {'id': 4430, 'name': 'pm25 µg/m³', 'parameter': {'id': 2, 'name': 'pm25', 'uni...

# %%
pd.set_option('display.max_colwidth', 200)
sensors = turncated_df[['sensors']]
print(sensors)
# Out:
#                                                                                                                                                                                                     sensors
# 12  [{'id': 4244, 'name': 'no2 µg/m³', 'parameter': {'id': 5, 'name': 'no2', 'units': 'µg/m³', 'displayName': 'NO₂ mass'}}, {'id': 4235, 'name': 'pm25 µg/m³', 'parameter': {'id': 2, 'name': 'pm25', 'u...
# 16  [{'id': 4275709, 'name': 'no µg/m³', 'parameter': {'id': 19843, 'name': 'no', 'units': 'µg/m³', 'displayName': 'NO mass'}}, {'id': 4461, 'name': 'o3 µg/m³', 'parameter': {'id': 3, 'name': 'o3', 'u...
# 19  [{'id': 4344, 'name': 'pm25 µg/m³', 'parameter': {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': 'PM2.5'}}, {'id': 160, 'name': 'so2 µg/m³', 'parameter': {'id': 6, 'name': 'so2', 'units...
# 21  [{'id': 4112, 'name': 'pm10 µg/m³', 'parameter': {'id': 1, 'name': 'pm10', 'units': 'µg/m³', 'displayName': 'PM10'}}, {'id': 163, 'name': 'so2 µg/m³', 'parameter': {'id': 6, 'name': 'so2', 'units'...
# 22  [{'id': 4215, 'name': 'pm25 µg/m³', 'parameter': {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': 'PM2.5'}}, {'id': 4369, 'name': 'pm10 µg/m³', 'parameter': {'id': 1, 'name': 'pm10', 'un...
# 35  [{'id': 5079263, 'name': 'no µg/m³', 'parameter': {'id': 19843, 'name': 'no', 'units': 'µg/m³', 'displayName': 'NO mass'}}, {'id': 5079262, 'name': 'no2 µg/m³', 'parameter': {'id': 5, 'name': 'no2...
# 39  [{'id': 7696649, 'name': 'no µg/m³', 'parameter': {'id': 19843, 'name': 'no', 'units': 'µg/m³', 'displayName': 'NO mass'}}, {'id': 4204, 'name': 'no2 µg/m³', 'parameter': {'id': 5, 'name': 'no2', ...
# 41  [{'id': 5079267, 'name': 'no µg/m³', 'parameter': {'id': 19843, 'name': 'no', 'units': 'µg/m³', 'displayName': 'NO mass'}}, {'id': 5079266, 'name': 'no2 µg/m³', 'parameter': {'id': 5, 'name': 'no2...
# 52  [{'id': 4310, 'name': 'o3 µg/m³', 'parameter': {'id': 3, 'name': 'o3', 'units': 'µg/m³', 'displayName': 'O₃ mass'}}, {'id': 4314, 'name': 'no2 µg/m³', 'parameter': {'id': 5, 'name': 'no2', 'units'...
# 53  [{'id': 4323, 'name': 'no2 µg/m³', 'parameter': {'id': 5, 'name': 'no2', 'units': 'µg/m³', 'displayName': 'NO₂ mass'}}, {'id': 4276237, 'name': 'no µg/m³', 'parameter': {'id': 19843, 'name': 'no',...
# 59  [{'id': 4358, 'name': 'pm10 µg/m³', 'parameter': {'id': 1, 'name': 'pm10', 'units': 'µg/m³', 'displayName': 'PM10'}}, {'id': 4459, 'name': 'no2 µg/m³', 'parameter': {'id': 5, 'name': 'no2', 'units...
# 62  [{'id': 4275884, 'name': 'no µg/m³', 'parameter': {'id': 19843, 'name': 'no', 'units': 'µg/m³', 'displayName': 'NO mass'}}, {'id': 4406, 'name': 'no2 µg/m³', 'parameter': {'id': 5, 'name': 'no2', ...
# 65  [{'id': 4504, 'name': 'pm10 µg/m³', 'parameter': {'id': 1, 'name': 'pm10', 'units': 'µg/m³', 'displayName': 'PM10'}}, {'id': 4430, 'name': 'pm25 µg/m³', 'parameter': {'id': 2, 'name': 'pm25', 'uni...

# %% [markdown]
# # Get measurements with sensor id

# %%
url = 'https://api.openaq.org/v3/sensors/4244/measurements?period_name=hour&date_from=2024-04-21T10%3A00%3A00%2B00%3A00&limit=100&page=1'
response = await session.get(url=url)
print(response)
result = response.json()
print(result['results'])
# Out:
# <Response [200 OK]>
# [{'value': 2.2, 'parameter': {'id': 5, 'name': 'no2', 'units': 'µg/m³', 'displayName': None}, 'period': {'label': '1hour', 'interval': '01:00:00', 'datetimeFrom': {'utc': '2024-04-21T10:00:00+00:00', 'local': '2024-04-21T12:00:00+02:00'}, 'datetimeTo': {'utc': '2024-04-21T11:00:00+00:00', 'local': '2024-04-21T13:00:00+02:00'}}, 'coordinates': None, 'summary': {'min': 2.2, 'q02': 2.2, 'q25': 2.2, 'median': 2.2, 'q75': 2.2, 'q98': 2.2, 'max': 2.2, 'avg': None, 'sd': None}, 'coverage': {'expectedCount': 1, 'expectedInterval': '01:00:00', 'observedCount': 1, 'observedInterval': '01:00:00', 'percentComplete': 100.0, 'percentCoverage': 100.0, 'datetimeFrom': {'utc': '2024-04-21T11:00:00+00:00', 'local': '2024-04-21T13:00:00+02:00'}, 'datetimeTo': {'utc': '2024-04-21T11:00:00+00:00', 'local': '2024-04-21T13:00:00+02:00'}}}, {'value': 3.2, 'parameter': {'id': 5, 'name': 'no2', 'units': 'µg/m³', 'displayName': None}, 'period': {'label': '1hour', 'interval': '01:00:00', 'datetimeFrom': {'utc': '2024-04-21T11:00:00+00:00', 'local': '2024-04-21T13:00:00+02:00'}, 'datetimeTo': {'utc': '2024-04-21T12:00:00+00:00', 'local': '2024-04-21T14:00:00+02:00'}}, 'coordinates': None, 'summary': {'min': 3.2, 'q02': 3.2, 'q25': 3.2, 'median': 3.2, 'q75': 3.2, 'q98': 3.2, 'max': 3.2, 'avg': None, 'sd': None}, 'coverage': {'expectedCount': 1, 'expectedInterval': '01:00:00', 'observedCount': 1, 'observedInterval': '01:00:00', 'percentComplete': 100.0, 'percentCoverage': 100.0, 'datetimeFrom': {'utc': '2024-04-21T12:00:00+00:00', 'local': '2024-04-21T14:00:00+02:00'}, 'datetimeTo': {'utc': '2024-04-21T12:00:00+00:00', 'local': '2024-04-21T14:00:00+02:00'}}}, {'value': 3.0, 'parameter': {'id': 5, 'name': 'no2', 'units': 'µg/m³', 'displayName': None}, 'period': {'label': '1hour', 'interval': '01:00:00', 'datetimeFrom': {'utc': '2024-04-21T12:00:00+00:00', 'local': '2024-04-21T14:00:00+02:00'}, 'datetimeTo': {'utc': '2024-04-21T13:00:00+00:00', 'local': '2024-04-21T15:00:00+02:00'}}, 'coordinates': None, 'summary': {'min': 3.0, 'q02': 3.0, 'q25': 3.0, 'median': 3.0, 'q75': 3.0, 'q98': 3.0, 'max': 3.0, 'avg': None, 'sd': None}, 'coverage': {'expectedCount': 1, 'expectedInterval': '01:00:00', 'observedCount': 1, 'observedInterval': '01:00:00', 'percentComplete': 100.0, 'percentCoverage': 100.0, 'datetimeFrom': {'utc': '2024-04-21T13:00:00+00:00', 'local': '2024-04-21T15:00:00+02:00'}, 'datetimeTo': {'utc': '2024-04-21T13:00:00+00:00', 'local': '2024-04-21T15:00:00+02:00'}}}, {'value': 4.3, 'parameter': {'id': 5, 'name': 'no2', 'units': 'µg/m³', 'displayName': None}, 'period': {'label': '1hour', 'interval': '01:00:00', 'datetimeFrom': {'utc': '2024-04-21T13:00:00+00:00', 'local': '2024-04-21T15:00:00+02:00'}, 'datetimeTo': {'utc': '2024-04-21T14:00:00+00:00', 'local': '2024-04-21T16:00:00+02:00'}}, 'coordinates': None, 'summary': {'min': 4.3, 'q02': 4.3, 'q25': 4.3, 'median': 4.3, 'q75': 4.3, 'q98': 4.3, 'max': 4.3, 'avg': None, 'sd': None}, 'coverage': {'expectedCount': 1, 'expectedInterval': '01:00:00', 'observedCount': 1, 'observedInterval': '01:00:00', 'percentComplete': 100.0, 'percentCoverage': 100.0, 'datetimeFrom': {'utc': '2024-04-21T14:00:00+00:00', 'local': '2024-04-21T16:00:00+02:00'}, 'datetimeTo': {'utc': '2024-04-21T14:00:00+00:00', 'local': '2024-04-21T16:00:00+02:00'}}}, {'value': 5.9, 'parameter': {'id': 5, 'name': 'no2', 'units': 'µg/m³', 'displayName': None}, 'period': {'label': '1hour', 'interval': '01:00:00', 'datetimeFrom': {'utc': '2024-04-21T14:00:00+00:00', 'local': '2024-04-21T16:00:00+02:00'}, 'datetimeTo': {'utc': '2024-04-21T15:00:00+00:00', 'local': '2024-04-21T17:00:00+02:00'}}, 'coordinates': None, 'summary': {'min': 5.9, 'q02': 5.9, 'q25': 5.9, 'median': 5.9, 'q75': 5.9, 'q98': 5.9, 'max': 5.9, 'avg': None, 'sd': None}, 'coverage': {'expectedCount': 1, 'expectedInterval': '01:00:00', 'observedCount': 1, 'observedInterval': '01:00:00', 'percentComplete': 100.0, 'percentCoverage': 100.0, 'datetimeFrom': {'utc': '2024-04-21T15:00:0 ...

# %%
from datetime import datetime, timedelta

# Get the current date and time
current_datetime = datetime.now()

# Calculate the datetime 24 hours ago
datetime_24_hours_ago = current_datetime - timedelta(hours=24)

# Print the result
print("24 hours ago was:", datetime_24_hours_ago)

datetime_str = datetime_24_hours_ago.strftime('%Y-%m-%dT%H:%M:%S%z')

print(datetime_str)

datetime_str_encoded = datetime_str.replace(':', '%3A').replace('+', '%2B')

print(datetime_str_encoded)
# Out:
# 24 hours ago was: 2024-04-21 18:48:20.168772
# 2024-04-21T18:48:20
# 2024-04-21T18%3A48%3A20

# %%
async def getLastDayMeasurements(sensorId, session):
    current_datetime = datetime.now()
    datetime_24_hours_ago = current_datetime - timedelta(hours=24)
    # Convert datetime object to string with timezone offset
    datetime_str = datetime_24_hours_ago.strftime('%Y-%m-%dT%H:%M:%S%z')
    # Replace characters with URL-encoded equivalents
    datetime_str_encoded = datetime_str.replace(':', '%3A').replace('+', '%2B')
    url = f'https://api.openaq.org/v3/sensors/{sensorId}/measurements?period_name=hour&date_from={datetime_str_encoded}&limit=100&page=1'
    # print(url)
    response = await session.get(url=url,timeout=10)
    if response.status_code == 500:
        print(f'Internal error for {sensorId}')
    result = response.json()
    return result['results']

# %%
res = await getLastDayMeasurements(sensorId=4461,session=session)
res
# Out:
# [{'value': 25.0,
#   'parameter': {'id': 3, 'name': 'o3', 'units': 'µg/m³', 'displayName': None},
#   'period': {'label': '1hour',
#    'interval': '01:00:00',
#    'datetimeFrom': {'utc': '2024-04-22T06:00:00+00:00',
#     'local': '2024-04-22T08:00:00+02:00'},
#    'datetimeTo': {'utc': '2024-04-22T07:00:00+00:00',
#     'local': '2024-04-22T09:00:00+02:00'}},
#   'coordinates': None,
#   'summary': {'min': 25.3,
#    'q02': 25.3,
#    'q25': 25.3,
#    'median': 25.3,
#    'q75': 25.3,
#    'q98': 25.3,
#    'max': 25.3,
#    'avg': None,
#    'sd': None},
#   'coverage': {'expectedCount': 1,
#    'expectedInterval': '01:00:00',
#    'observedCount': 1,
#    'observedInterval': '01:00:00',
#    'percentComplete': 100.0,
#    'percentCoverage': 100.0,
#    'datetimeFrom': {'utc': '2024-04-22T07:00:00+00:00',
#     'local': '2024-04-22T09:00:00+02:00'},
#    'datetimeTo': {'utc': '2024-04-22T07:00:00+00:00',
#     'local': '2024-04-22T09:00:00+02:00'}}},
#  {'value': 11.0,
#   'parameter': {'id': 3, 'name': 'o3', 'units': 'µg/m³', 'displayName': None},
#   'period': {'label': '1hour',
#    'interval': '01:00:00',
#    'datetimeFrom': {'utc': '2024-04-22T07:00:00+00:00',
#     'local': '2024-04-22T09:00:00+02:00'},
#    'datetimeTo': {'utc': '2024-04-22T08:00:00+00:00',
#     'local': '2024-04-22T10:00:00+02:00'}},
#   'coordinates': None,
#   'summary': {'min': 10.9,
#    'q02': 10.9,
#    'q25': 10.9,
#    'median': 10.9,
#    'q75': 10.9,
#    'q98': 10.9,
#    'max': 10.9,
#    'avg': None,
#    'sd': None},
#   'coverage': {'expectedCount': 1,
#    'expectedInterval': '01:00:00',
#    'observedCount': 1,
#    'observedInterval': '01:00:00',
#    'percentComplete': 100.0,
#    'percentCoverage': 100.0,
#    'datetimeFrom': {'utc': '2024-04-22T08:00:00+00:00',
#     'local': '2024-04-22T10:00:00+02:00'},
#    'datetimeTo': {'utc': '2024-04-22T08:00:00+00:00',
#     'local': '2024-04-22T10:00:00+02:00'}}},
#  {'value': 42.0,
#   'parameter': {'id': 3, 'name': 'o3', 'units': 'µg/m³', 'displayName': None},
#   'period': {'label': '1hour',
#    'interval': '01:00:00',
#    'datetimeFrom': {'utc': '2024-04-22T08:00:00+00:00',
#     'local': '2024-04-22T10:00:00+02:00'},
#    'datetimeTo': {'utc': '2024-04-22T09:00:00+00:00',
#     'local': '2024-04-22T11:00:00+02:00'}},
#   'coordinates': None,
#   'summary': {'min': 41.9,
#    'q02': 41.9,
#    'q25': 41.9,
#    'median': 41.9,
#    'q75': 41.9,
#    'q98': 41.9,
#    'max': 41.9,
#    'avg': None,
#    'sd': None},
#   'coverage': {'expectedCount': 1,
#    'expectedInterval': '01:00:00',
#    'observedCount': 1,
#    'observedInterval': '01:00:00',
#    'percentComplete': 100.0,
#    'percentCoverage': 100.0,
#    'datetimeFrom': {'utc': '2024-04-22T09:00:00+00:00',
#     'local': '2024-04-22T11:00:00+02:00'},
#    'datetimeTo': {'utc': '2024-04-22T09:00:00+00:00',
#     'local': '2024-04-22T11:00:00+02:00'}}},
#  {'value': 79.0,
#   'parameter': {'id': 3, 'name': 'o3', 'units': 'µg/m³', 'displayName': None},
#   'period': {'label': '1hour',
#    'interval': '01:00:00',
#    'datetimeFrom': {'utc': '2024-04-22T09:00:00+00:00',
#     'local': '2024-04-22T11:00:00+02:00'},
#    'datetimeTo': {'utc': '2024-04-22T10:00:00+00:00',
#     'local': '2024-04-22T12:00:00+02:00'}},
#   'coordinates': None,
#   'summary': {'min': 79.4,
#    'q02': 79.4,
#    'q25': 79.4,
#    'median': 79.4,
#    'q75': 79.4,
#    'q98': 79.4,
#    'max': 79.4,
#    'avg': None,
#    'sd': None},
#   'coverage': {'expectedCount': 1,
#    'expectedInterval': '01:00:00',
#    'observedCount': 1,
#    'observedInterval': '01:00:00',
#    'percentComplete': 100.0,
#    'percentCoverage': 100.0,
#    'datetimeFrom': {'utc': '2024-04-22T10:00:00+00:00',
#     'local': '2024-04-22T12:00:00+02:00'},
#    'datetimeTo': {'utc': '2024-04-22T10:00:00+00:00',
#     'local': '2024-04-22T12:00:00+02:00'}}},
#  {'value': 75.0,
#   'parameter': {'id': 3, 'name': 'o3', 'units': 'µg/m³', 'displayName': None},
#   'period': {'label': '1hour',
#    'interval': '01:00:00',
#    'datetimeFrom': {'utc': '2024-04-22T10:00:00+00:00',
#     'local': '2024-04-22T12:00:00+02:00'},
#    'datetimeTo': {'utc': '2024-04-22T11:00:00+00:00',
#     'local': '2024-04-22T13:00:00+02:00'}},
#   'coordinates': None,
#   'summary': {'min': 75.0,
#    'q02': 75.0,
#    'q25': 75.0,
#    'median': 75.0,
#    'q75': 75.0,
#    'q98': 75.0,
#    'max': 75.0,
#    'avg': None,
#    'sd': None},
#   'coverage': {'expectedCount': 1,
#    'expectedInterval': '01:00:00',
#    'observedCount': 1,
#    'observedInterval': '01:00:00',
#    'percentComplete': 100.0,
#    'percentCoverage': 100.0,
#    'datetimeFrom': {'utc': '2024-04-22T11:00:00+00:00',
#     'local': '2024-04-22T13:00:00+02:00'},
#    'datetimeTo': {'utc': '2024-04-22T11:00:00+00:00',
#     'local': '2024-04-22T13:00:00+02:00'}}},
#  {'value': 80.0,
#   'parameter': {'id': 3, 'name': 'o3', 'units': 'µg/m³', 'displayName': None},
#   'period': {'label': '1hour',
#    'interval': '01:00:00',
#    'datetimeFrom': {'utc': '2024-04-22T11:00:00+00:00',
#     'local': '2024-04-22T13:00:00+02:00'},
#    'datetimeTo': {'utc': '2024-04-22T12:00:00+00:00',
#     'local': '2024-04-22T14:00:00+02:00'}},
#   'coordinates': None,
#   'summary': {'min': 80.4,
#    'q02': 80.4,
#    'q25': 80.4,
#    'median': 80.4,
#    'q75': 80.4,
#    'q98': 80.4,
#    'max': 80.4,
#    'avg': None,
#    'sd': None},
#   'coverage': {'expectedCount': 1,
#    'expectedInterval': '01:00:00',
#    'observedCount': 1,
#    'observedInterval': '01:00:00',
#    'percentComplete': 100.0,
#    'percentCoverage': 100.0,
#    'datetimeFrom': {'utc': '2024-04-22T12:00:00+00:00',
#     'local': '2024-04-22T14:00:00+02:00'},
#    'datetimeTo': {'utc': '2024-04-22T12:00:00+00:00',
#     'local': '2024-04-22T14:00:00+02:00'}}},
#  {'value': 89.0,
#   'parameter': {'id': 3, 'name': 'o3', 'units': 'µg/m³', 'displayName': None},
#   'period': {'label': '1hour',
#    'interval': '01:00:00',
#    'datetimeFrom': {'utc': '2024-04-22T12:00:00+00:00',
#     'local': '2024-04-22T14:00:00+02:00'},
#    'datetimeTo': {'utc': '2024-04-22T13:00:00+00:00',
#     'local': '2024-04-22T15:00:00+02:00'}},
#   'coordinates': None,
#   'summary': {'min': 89.4,
#    'q02': 89.4,
#    'q25': 89.4,
#    'median': 89.4,
#    'q75': 89.4,
#    'q98': 89.4,
#    'max': 89.4,
#    'avg': None,
#    'sd': None},
#   'coverage': {'expectedCount': 1,
#    'expectedInterval': '01:00:00',
#    'observedCount': 1,
#    'observedInterval': '01:00:00',
#    'percentComplete': 100.0,
#    'percentCoverage': 100.0,
#    'datetimeFrom': {'utc': '2024-04-22T13:00:00+00:00',
#     'local': '2024-04-22T15:00:00+02:00'},
#    'datetimeTo': {'utc': '2024-04-22T13:00:00+00:00',
#     'local': '2024-04-22T15:00:00+02:00'}}},
#  {'value': 91.0,
#   'parameter': {'id': 3, 'name': 'o3', 'units': 'µg/m³', 'displayName': None},
#   'period': {'label': '1hour',
#    'interval': '01:00:00',
#    'datetimeFrom': {'utc': '2024-04-22T13:00:00+00:00',
#     'local': '2024-04-22T15:00:00+02:00'},
#    'datetimeTo': {'utc': '2024-04-22T14:00:00+00:00',
#     'local': '2024-04-22T16:00:00+02:00'}},
#   'coordinates': None,
#   'summary': {'min': 91.4,
#    'q02': 91.4,
#    'q25': 91.4,
#    'median': 91.4,
#    'q75': 91.4,
#    'q98': 91.4,
#    'max': 91.4,
#    'avg': None,
#    'sd': None},
#   'coverage': {'expectedCount': 1,
#    'expectedInterval': '01:00:00',
#    'observedCount': 1,
#    'observedInterval': '01:00:00',
#    'percentComplete': 100.0,
#    'percentCoverage': 100.0,
#    'datetimeFrom': {'utc': '2024-04-22T14:00:00+00:00',
#     'local': '2024-04-22T16:00:00+02:00'},
#    'datetimeTo': {'utc': '2024-04-22T14:00:00+00:00',
#     'local': '2024-04-22T16:00:00+02:00'}}},
#  {'value': 95.0,
#   'parameter': {'id': 3, 'name': 'o3', 'units': 'µg/m³', 'displayName': None},
#   'period': {'label': '1hour',
#    'interval': '01:00:00',
#    'datetimeFrom': {'utc': '2024-04-22T14:00:00+00:00',
#     'local': '2024-04-22T16:00:00+02:00'},
#    'datetimeTo': {'utc': '2024-04-22T15:00:00+00:00',
#     'local': '2024-04-22T17:00:00+02:00'}},
#   'coordinates': None,
#   'summary': {'min': 95.1,
#    'q02': 95.1,
#    'q25': 95.1,
#    'median': 95.1,
#    'q75': 95.1,
#    'q98': 95.1,
#    'max': 95.1,
#    'avg': None,
#    'sd': None},
#   'coverage': {'expectedCount': 1,
#    'expectedInterval': '01:00:00',
#    'observedCount': 1,
#    'observedInterval': '01:00:00',
#    'percentComplete': 100.0,
#    'percentCoverage': 100.0,
#    'datetimeFrom': {'utc': '2024-04-22T15:00:00+00:00',
#     'local': '2024-04-22T17:00:00+02:00'},
#    'datetimeTo': {'utc': '2024-04-22T15:00:00+00:00',
#     'local': '2024-04-22T17:00:00+02:00'}}}]

# %%
def getAvgSensor(measurements):
    sum = 0
    name = measurements[0]['parameter']['name']
    unit = measurements[0]['parameter']['units']
    for measurement in measurements:
        sum += measurement['value']
    avg = sum / len(measurements)
    return {"name":name,"unit":unit,"avg":avg}

# %%
getAvgSensor(res)
# Out:
# {'name': 'o3', 'unit': 'µg/m³', 'avg': 65.22222222222223}

# %%
from datetime import datetime, timedelta

# %%
current_datetime = datetime.now()
datetime_24_hours_ago = current_datetime - timedelta(hours=24)    
# Convert datetime object to string with timezone offset
to_datetime_str = current_datetime.strftime('%Y-%m-%dT%H:%M:%S%z')
before_datetime_str = datetime_24_hours_ago.strftime('%Y-%m-%dT%H:%M:%S%z')
# Replace characters with URL-encoded equivalents
to_datetime_str_encoded = to_datetime_str.replace(':', '%3A').replace('+', '%2B')
before_datetime_str_encoded = before_datetime_str.replace(':', '%3A').replace('+', '%2B')

city = "AMSTERDAM"

# %%
url = f'https://api.openaq.org/v2/measurements?date_from={before_datetime_str_encoded}&date_to={to_datetime_str_encoded}&limit=1000&page=1&offset=0&sort=desc&radius=1000&city={city}&order_by=datetime'
response = await session.get(url=url)
result = response.json()
result = result['results']
len(result)
# Out:
# 399

# %%
df = pd.DataFrame(result)

# %%
dimenstraat_df = df[df["locationId"]==80]
dimenstraat_df.head()
# Out:
#    locationId                    location parameter  value  \
# 0          80  Amsterdam-Van Diemenstraat      pm10    8.6
# 1          80  Amsterdam-Van Diemenstraat      pm10    5.2
# 2          80  Amsterdam-Van Diemenstraat      pm10    6.1
# 3          80  Amsterdam-Van Diemenstraat      pm10    9.6
# 4          80  Amsterdam-Van Diemenstraat      pm10    5.7
#
#                                                 date   unit  \
# 0  {'utc': '2024-04-23T01:00:00+00:00', 'local': ...  µg/m³
# 1  {'utc': '2024-04-23T00:00:00+00:00', 'local': ...  µg/m³
# 2  {'utc': '2024-04-22T23:00:00+00:00', 'local': ...  µg/m³
# 3  {'utc': '2024-04-22T22:00:00+00:00', 'local': ...  µg/m³
# 4  {'utc': '2024-04-22T21:00:00+00:00', 'local': ...  µg/m³
#
#                                          coordinates country  city  isMobile  \
# 0  {'latitude': 52.38998299964, 'longitude': 4.88...      NL  None     False
# 1  {'latitude': 52.38998299964, 'longitude': 4.88...      NL  None     False
# 2  {'latitude': 52.38998299964, 'longitude': 4.88...      NL  None     False
# 3  {'latitude': 52.38998299964, 'longitude': 4.88...      NL  None     False
# 4  {'latitude': 52.38998299964, 'longitude': 4.88...      NL  None     False
#
#   isAnalysis                     entity       sensorType
# 0       None  Governmental Organization  reference grade
# 1       None  Governmental Organization  reference grade
# 2       None  Governmental Organization  reference grade
# 3       None  Governmental Organization  reference grade
# 4       None  Governmental Organization  reference grade

# %%
grouped_data = df.groupby(['locationId','location', 'parameter','unit'])['value'].mean().reset_index()

grouped_data
# Out:
#     locationId                              location parameter   unit  \
# 0           80            Amsterdam-Van Diemenstraat       no2  µg/m³
# 1           80            Amsterdam-Van Diemenstraat        o3  µg/m³
# 2           80            Amsterdam-Van Diemenstraat      pm10  µg/m³
# 3           80            Amsterdam-Van Diemenstraat      pm25  µg/m³
# 4           95                  Amsterdam-Vondelpark       no2  µg/m³
# 5           95                  Amsterdam-Vondelpark        o3  µg/m³
# 6           95                  Amsterdam-Vondelpark      pm10  µg/m³
# 7           95                  Amsterdam-Vondelpark      pm25  µg/m³
# 8           98                  Amsterdam-Westerpark      pm10  µg/m³
# 9           98                  Amsterdam-Westerpark      pm25  µg/m³
# 10          98                  Amsterdam-Westerpark       so2  µg/m³
# 11         101                     Amsterdam-Hoogtij       no2  µg/m³
# 12         101                     Amsterdam-Hoogtij      pm10  µg/m³
# 13         101                     Amsterdam-Hoogtij      pm25  µg/m³
# 14         101                     Amsterdam-Hoogtij       so2  µg/m³
# 15         102                 Amsterdam-Einsteinweg       no2  µg/m³
# 16         102                 Amsterdam-Einsteinweg      pm10  µg/m³
# 17         102                 Amsterdam-Einsteinweg      pm25  µg/m³
# 18        2305                 Amsterdam-Spaarnwoude       no2  µg/m³
# 19        2305                 Amsterdam-Spaarnwoude      pm10  µg/m³
# 20        2305                 Amsterdam-Spaarnwoude      pm25  µg/m³
# 21        2315               Amsterdam-Haarlemmerweg       no2  µg/m³
# 22        2319                 Amsterdam-Oude Schans       no2  µg/m³
# 23        2349           Amsterdam-Nieuwendammerdijk       no2  µg/m³
# 24        2349           Amsterdam-Nieuwendammerdijk        o3  µg/m³
# 25        2353      Amsterdam-Kantershof (Zuid Oost)       no2  µg/m³
# 26        2367         Amsterdam-Jan van Galenstraat       no2  µg/m³
# 27        2367         Amsterdam-Jan van Galenstraat      pm10  µg/m³
# 28        2378  Amsterdam-Sportpark Ookmeer (Osdorp)       no2  µg/m³
# 29        2383             Amsterdam-Stadhouderskade       no2  µg/m³
# 30        2383             Amsterdam-Stadhouderskade      pm10  µg/m³
# 31        2383             Amsterdam-Stadhouderskade      pm25  µg/m³
#
#         value
# 0    9.192308
# 1   90.530769
# 2    6.750000
# 3    2.884615
# 4   10.553846
# 5   93.150000
# 6   10.408333
# 7    6.200000
# 8   10.958333
# 9    3.423077
# 10   2.453846
# 11  10.176923
# 12   6.066667
# 13   2.907692
# 14   0.253846
# 15  38.946154
# 16  11.483333
# 17   8.261538
# 18  10.400000
# 19   6.233333
# 20   2.930769
# 21  20.969231
# 22  11.507692
# 23   4.515385
# 24  86.592308
# 25   3.992308
# 26  19.030769
# 27   6.925000
# 28  10.300000
# 29  18.153846
# 30   7.191667
# 31   4.923077

# %%
avg_amsterdam = grouped_data.groupby(['parameter','unit'])['value'].mean().reset_index()

# %%
avg_amsterdam['locationId'] = 0
avg_amsterdam['location'] = "Amsterdam-General"
avg_amsterdam
# Out:
#   parameter   unit      value  locationId           location
# 0       no2  µg/m³  13.978205           0  Amsterdam-General
# 1        o3  µg/m³  90.091026           0  Amsterdam-General
# 2      pm10  µg/m³   8.252083           0  Amsterdam-General
# 3      pm25  µg/m³   4.504396           0  Amsterdam-General
# 4       so2  µg/m³   1.353846           0  Amsterdam-General

# %%
grouped_data = pd.concat([grouped_data,avg_amsterdam],ignore_index=True)
grouped_data
# Out:
#     locationId                              location parameter   unit  \
# 0           80            Amsterdam-Van Diemenstraat       no2  µg/m³
# 1           80            Amsterdam-Van Diemenstraat        o3  µg/m³
# 2           80            Amsterdam-Van Diemenstraat      pm10  µg/m³
# 3           80            Amsterdam-Van Diemenstraat      pm25  µg/m³
# 4           95                  Amsterdam-Vondelpark       no2  µg/m³
# 5           95                  Amsterdam-Vondelpark        o3  µg/m³
# 6           95                  Amsterdam-Vondelpark      pm10  µg/m³
# 7           95                  Amsterdam-Vondelpark      pm25  µg/m³
# 8           98                  Amsterdam-Westerpark      pm10  µg/m³
# 9           98                  Amsterdam-Westerpark      pm25  µg/m³
# 10          98                  Amsterdam-Westerpark       so2  µg/m³
# 11         101                     Amsterdam-Hoogtij       no2  µg/m³
# 12         101                     Amsterdam-Hoogtij      pm10  µg/m³
# 13         101                     Amsterdam-Hoogtij      pm25  µg/m³
# 14         101                     Amsterdam-Hoogtij       so2  µg/m³
# 15         102                 Amsterdam-Einsteinweg       no2  µg/m³
# 16         102                 Amsterdam-Einsteinweg      pm10  µg/m³
# 17         102                 Amsterdam-Einsteinweg      pm25  µg/m³
# 18        2305                 Amsterdam-Spaarnwoude       no2  µg/m³
# 19        2305                 Amsterdam-Spaarnwoude      pm10  µg/m³
# 20        2305                 Amsterdam-Spaarnwoude      pm25  µg/m³
# 21        2315               Amsterdam-Haarlemmerweg       no2  µg/m³
# 22        2319                 Amsterdam-Oude Schans       no2  µg/m³
# 23        2349           Amsterdam-Nieuwendammerdijk       no2  µg/m³
# 24        2349           Amsterdam-Nieuwendammerdijk        o3  µg/m³
# 25        2353      Amsterdam-Kantershof (Zuid Oost)       no2  µg/m³
# 26        2367         Amsterdam-Jan van Galenstraat       no2  µg/m³
# 27        2367         Amsterdam-Jan van Galenstraat      pm10  µg/m³
# 28        2378  Amsterdam-Sportpark Ookmeer (Osdorp)       no2  µg/m³
# 29        2383             Amsterdam-Stadhouderskade       no2  µg/m³
# 30        2383             Amsterdam-Stadhouderskade      pm10  µg/m³
# 31        2383             Amsterdam-Stadhouderskade      pm25  µg/m³
# 32           0                     Amsterdam-General       no2  µg/m³
# 33           0                     Amsterdam-General        o3  µg/m³
# 34           0                     Amsterdam-General      pm10  µg/m³
# 35           0                     Amsterdam-General      pm25  µg/m³
# 36           0                     Amsterdam-General       so2  µg/m³
#
#         value
# 0    9.192308
# 1   90.530769
# 2    6.750000
# 3    2.884615
# 4   10.553846
# 5   93.150000
# 6   10.408333
# 7    6.200000
# 8   10.958333
# 9    3.423077
# 10   2.453846
# 11  10.176923
# 12   6.066667
# 13   2.907692
# 14   0.253846
# 15  38.946154
# 16  11.483333
# 17   8.261538
# 18  10.400000
# 19   6.233333
# 20   2.930769
# 21  20.969231
# 22  11.507692
# 23   4.515385
# 24  86.592308
# 25   3.992308
# 26  19.030769
# 27   6.925000
# 28  10.300000
# 29  18.153846
# 30   7.191667
# 31   4.923077
# 32  13.978205
# 33  90.091026
# 34   8.252083
# 35   4.504396
# 36   1.353846

# %%
# Location names list amsterdam
location_names = grouped_data['location'].unique()

for location_name in location_names:
    print(location_name)
# Out:
# Amsterdam-Van Diemenstraat
# Amsterdam-Vondelpark
# Amsterdam-Westerpark
# Amsterdam-Hoogtij
# Amsterdam-Einsteinweg
# Amsterdam-Spaarnwoude
# Amsterdam-Haarlemmerweg
# Amsterdam-Oude Schans
# Amsterdam-Nieuwendammerdijk
# Amsterdam-Kantershof (Zuid Oost)
# Amsterdam-Jan van Galenstraat
# Amsterdam-Sportpark Ookmeer (Osdorp)
# Amsterdam-Stadhouderskade
# Amsterdam-General

# %% [markdown]
# # InfluxDB

# %%
from dotenv import load_dotenv
import influxdb_client, os ,time
from influxdb_client import InfluxDBClient, Point, WritePrecision, DeletePredicateRequest
from influxdb_client.client.write_api import SYNCHRONOUS

load_dotenv()

token = os.getenv("INFLUXDB_TOKEN")
org = os.getenv("INFLUXDB_ORG")
url = os.getenv("INFLUXDB_URL")

client = influxdb_client.InfluxDBClient(url=url, token=token, org=org)

print(f'{token} {org} {url}')
# Out:
# v5rg1Z1DD8jBqeaIo9ITKsleRdg-SHPAe88yqyRgr5WcUTHhiqw0qDoxpsVcKm8CFRoLO8gul2_aZrd75uoBLg== ORG_NAME http://localhost:8086

# %% [markdown]
# add data

# %%
bucket="Demo_Data_Pipeline"

write_api = client.write_api(write_options=SYNCHRONOUS)
   
for index,row in grouped_data.iterrows():
  point = (
    Point("amsterdam_measurement")
    .tag("location", row['location'])
    .tag("unit",row['unit'])
    .field(row['parameter'],row['value'])
  )
  write_api.write(bucket=bucket, org="ORG_NAME", record=point)

# %% [markdown]
# read data

# %%
query_api = client.query_api()

query = """from(bucket: "Demo_Data_Pipeline")
 |> range(start: -10m)
 |> filter(fn: (r) => r._measurement == "amsterdam_measurement")"""
tables = query_api.query(query, org="ORG_NAME")

for table in tables:
  for record in table.records:
    print(record)
# Out:
# FluxRecord() table: 0, {'result': '_result', 'table': 0, '_start': datetime.datetime(2024, 4, 23, 11, 22, 34, 375667, tzinfo=tzutc()), '_stop': datetime.datetime(2024, 4, 23, 11, 32, 34, 375667, tzinfo=tzutc()), '_time': datetime.datetime(2024, 4, 23, 11, 32, 27, 874382, tzinfo=tzutc()), '_value': 38.94615384615385, '_field': 'no2', '_measurement': 'amsterdam_measurement', 'location': 'Amsterdam-Einsteinweg', 'unit': 'µg/m³'}
# FluxRecord() table: 1, {'result': '_result', 'table': 1, '_start': datetime.datetime(2024, 4, 23, 11, 22, 34, 375667, tzinfo=tzutc()), '_stop': datetime.datetime(2024, 4, 23, 11, 32, 34, 375667, tzinfo=tzutc()), '_time': datetime.datetime(2024, 4, 23, 11, 32, 27, 877516, tzinfo=tzutc()), '_value': 11.483333333333334, '_field': 'pm10', '_measurement': 'amsterdam_measurement', 'location': 'Amsterdam-Einsteinweg', 'unit': 'µg/m³'}
# FluxRecord() table: 2, {'result': '_result', 'table': 2, '_start': datetime.datetime(2024, 4, 23, 11, 22, 34, 375667, tzinfo=tzutc()), '_stop': datetime.datetime(2024, 4, 23, 11, 32, 34, 375667, tzinfo=tzutc()), '_time': datetime.datetime(2024, 4, 23, 11, 32, 27, 880688, tzinfo=tzutc()), '_value': 8.261538461538462, '_field': 'pm25', '_measurement': 'amsterdam_measurement', 'location': 'Amsterdam-Einsteinweg', 'unit': 'µg/m³'}
# FluxRecord() table: 3, {'result': '_result', 'table': 3, '_start': datetime.datetime(2024, 4, 23, 11, 22, 34, 375667, tzinfo=tzutc()), '_stop': datetime.datetime(2024, 4, 23, 11, 32, 34, 375667, tzinfo=tzutc()), '_time': datetime.datetime(2024, 4, 23, 11, 32, 27, 933753, tzinfo=tzutc()), '_value': 13.978205128205127, '_field': 'no2', '_measurement': 'amsterdam_measurement', 'location': 'Amsterdam-General', 'unit': 'µg/m³'}
# FluxRecord() table: 4, {'result': '_result', 'table': 4, '_start': datetime.datetime(2024, 4, 23, 11, 22, 34, 375667, tzinfo=tzutc()), '_stop': datetime.datetime(2024, 4, 23, 11, 32, 34, 375667, tzinfo=tzutc()), '_time': datetime.datetime(2024, 4, 23, 11, 32, 27, 937008, tzinfo=tzutc()), '_value': 90.09102564102564, '_field': 'o3', '_measurement': 'amsterdam_measurement', 'location': 'Amsterdam-General', 'unit': 'µg/m³'}
# FluxRecord() table: 5, {'result': '_result', 'table': 5, '_start': datetime.datetime(2024, 4, 23, 11, 22, 34, 375667, tzinfo=tzutc()), '_stop': datetime.datetime(2024, 4, 23, 11, 32, 34, 375667, tzinfo=tzutc()), '_time': datetime.datetime(2024, 4, 23, 11, 32, 27, 940140, tzinfo=tzutc()), '_value': 8.252083333333333, '_field': 'pm10', '_measurement': 'amsterdam_measurement', 'location': 'Amsterdam-General', 'unit': 'µg/m³'}
# FluxRecord() table: 6, {'result': '_result', 'table': 6, '_start': datetime.datetime(2024, 4, 23, 11, 22, 34, 375667, tzinfo=tzutc()), '_stop': datetime.datetime(2024, 4, 23, 11, 32, 34, 375667, tzinfo=tzutc()), '_time': datetime.datetime(2024, 4, 23, 11, 32, 27, 943258, tzinfo=tzutc()), '_value': 4.504395604395604, '_field': 'pm25', '_measurement': 'amsterdam_measurement', 'location': 'Amsterdam-General', 'unit': 'µg/m³'}
# FluxRecord() table: 7, {'result': '_result', 'table': 7, '_start': datetime.datetime(2024, 4, 23, 11, 22, 34, 375667, tzinfo=tzutc()), '_stop': datetime.datetime(2024, 4, 23, 11, 32, 34, 375667, tzinfo=tzutc()), '_time': datetime.datetime(2024, 4, 23, 11, 32, 27, 946171, tzinfo=tzutc()), '_value': 1.353846153846154, '_field': 'so2', '_measurement': 'amsterdam_measurement', 'location': 'Amsterdam-General', 'unit': 'µg/m³'}
# FluxRecord() table: 8, {'result': '_result', 'table': 8, '_start': datetime.datetime(2024, 4, 23, 11, 22, 34, 375667, tzinfo=tzutc()), '_stop': datetime.datetime(2024, 4, 23, 11, 32, 34, 375667, tzinfo=tzutc()), '_time': datetime.datetime(2024, 4, 23, 11, 32, 27, 892679, tzinfo=tzutc()), '_value': 20.969230769230766, '_field': 'no2', '_measurement': 'amsterdam_measurement', 'location': 'Amsterdam-Haarlemmerweg', 'unit': 'µg/m³'}
# FluxRecord() table: 9, {'result': '_result', 'table': 9, '_start': datetime.datetime(2024, 4, 23, 11, 22, 34, 375667, tzinfo=tzutc()), '_stop': datetime.datetime(2024, 4, 23, 11, 32, 34, 375667, tzinfo=tzutc()), '_time': datetime.datetime(2024, 4, 23, 11, 32, 27, 860186, tzinfo=tzutc()), '_value': 10.176923076923078, '_field': 'no2', '_measurement': 'amsterdam_measurement', 'location': 'Amsterdam-Hoogtij', 'unit': 'µg/m³'}
# FluxRecord() table: 10, {'result': '_result', 'table': 10, '_start': datetime.datetime(2024, 4, 23, 11, 22, 34, 375667, tzinfo=tzutc()), '_stop': datetime.datetime(2024, 4, 23, 11, 32, 34, 375667, tzinfo=tzutc()), '_time': datetime.datetime(2024, 4, 23, 11, 32, 27, 863722, tzinfo=tzutc()), '_value': 6.066666666666666, '_field': 'pm10', '_measurement': 'amsterdam_measurement', 'location': 'Amsterdam-Hoogtij', 'unit': 'µg/m³'}
# FluxRecord() table: 11, {'result': '_result', 'table': 11, '_start': datetime.datetime(2024, 4, 23, 11, 22, 34, 375667, tzinfo=tzutc()), '_stop': datetime.datetime(2024, 4, 23, 11, 32, 34, 375667, tzinfo=tzutc()), '_time': datetime.datetime(2024, 4, 23, 11, 32, 27, 867596, tzinfo=tzutc()), '_value': 2.9076923076923076, '_field': 'pm25', '_measurement': 'amsterdam_measurement', 'location': 'Amsterdam-Hoogtij', 'unit': 'µg/m³'}
# FluxRecord() table: 12, {'result': '_result', 'table': 12, '_start': datetime.datetime(2024, 4, 23, 11, 22, 34, 375667, tzinfo=tzutc()), '_stop': datetime.datetime(2024, 4, 23, 11, 32, 34, 375667, tzinfo=tzutc()), '_time': datetime.datetime(2024, 4, 23, 11, 32, 27, 871033, tzinfo=tzutc()), '_value': 0.25384615384615383, '_field': 'so2', '_measurement': 'amsterdam_measurement', 'location': 'Amsterdam-Hoogtij', 'unit': 'µg/m³'}
# FluxRecord() table: 13, {'result': '_result', 'table': 13, '_start': datetime.datetime(2024, 4, 23, 11, 22, 34, 375667, tzinfo=tzutc()), '_stop': datetime.datetime(2024, 4, 23, 11, 32, 34, 375667, tzinfo=tzutc()), '_time': datetime.datetime(2024, 4, 23, 11, 32, 27, 910905, tzinfo=tzutc()), '_value': 19.03076923076923, '_field': 'no2', '_measurement': 'amsterdam_measurement', 'location': 'Amsterdam-Jan van Galenstraat', 'unit': 'µg/m³'}
# FluxRecord() table: 14, {'result': '_result', 'table': 14, '_start': datetime.datetime(2024, 4, 23, 11, 22, 34, 375667, tzinfo=tzutc()), '_stop': datetime.datetime(2024, 4, 23, 11, 32, 34, 375667, tzinfo=tzutc()), '_time': datetime.datetime(2024, 4, 23, 11, 32, 27, 914505, tzinfo=tzutc()), '_value': 6.925, '_field': 'pm10', '_measurement': 'amsterdam_measurement', 'location': 'Amsterdam-Jan van Galenstraat', 'unit': 'µg/m³'}
# FluxRecord() table: 15, {'result': '_result', 'table': 15, '_start': datetime.datetime(2024, 4, 23, 11, 22, 34, 375667, tzinfo=tzutc()), '_stop': datetime.datetime(2024, 4, 23, 11, 32, 34, 375667, tzinfo=tzutc()), '_time': datetime.datetime(2024, 4, 23, 11, 32, 27, 906890, tzinfo=tzutc()), '_value': 3.9923076923076923, '_field': 'no2', '_measurement': 'amsterdam_measurement', 'location': 'Amsterdam-Kantershof (Zuid Oost)', 'unit': 'µg/m³'}
# FluxRecord() table: 16, {'result': '_result', 'table': 16, '_start': datetime.datetime(2024, 4, 23, 11, 22, 34, 375667, tzinfo=tzutc()), '_stop': datetime.datetime(2024, 4, 23, 11, 32, 34, 375667, tzinfo=tzutc()), '_time': datetime.datetime(2024, 4, 23, 11, 32, 27, 900160, tzinfo=tzutc()), '_value': 4.515384615384615, '_field': 'no2', '_measurement': 'amsterdam_measurement', 'location': 'Amsterdam-Nieuwendammerdijk', 'unit': 'µg/m³'}
# FluxRecord() table: 17, {'result': '_result', 'table': 17, '_start': datetime.datetime(2024, 4, 23, 11, 22, 34, 375667, tzinfo=tzutc()), '_stop': datetime.datetime(2024, 4, 23, 11, 32, 34, 375667, tzinfo=tzutc()), '_time': datetime.datetime(2024, 4, 23, 11, 32, 27, 903341, tzinfo=tzutc()), '_value': 86.5923076923077, '_field': 'o3', '_measurement': 'amsterdam_measurement', 'location': 'Amsterdam-Nieuwendammerdijk', 'unit': 'µg/m³'}
# FluxRecord() table: 18, {'result': '_result', 'table': 18, '_start': datetime.datetime(2024, 4, 23, 11, 22, 34, 375667, tzinfo=tzutc()), '_stop': datetime.datetime(2024, 4, 23, 11, 32, 34, 375667, tzinfo=tzutc()), '_time': datetime.datetime(2024, 4, 23, 11, 32, 27, 896707, tzinfo=tzutc()), '_value': 11.507692307692308, '_field': 'no2', '_measurement': 'amsterdam_measurement', 'location': 'Amsterdam-Oude Schans', 'unit': 'µg/m³'}
# FluxRecord() table: 19, {'result': '_result', 'table': 19, '_start': datetime.datetime(2024, 4, 23, 11, 22, 34, 375667, tzinfo=tzutc()), '_stop': datetime.datetime(2024, 4, 23, 11, 32, 34, 375667, tzinfo=tzutc()), '_time': datetime.datetime(2024, 4, 23, 11, 32, 27, 883525, tzinfo=tzutc()), '_value': 10.399999999999999, '_field': 'no2', '_measurement': 'amsterdam_measurement', 'location': 'Amsterdam-Spaarnwoude', 'unit': 'µg/m³'}
# FluxRecord() table: 20, {'result': '_result', 'table': 20, '_start': datetime.datetime(2024, 4, 23, 11, 22, 34, 375667, tzinfo=tzutc()), '_stop': datetime.datetime(2024, 4, 23, 11, 32, 34, 375667, tzinfo=tzutc()), '_time': datetime.datetime(2024, 4, 23, 11, 32, 27, 886257, tzinfo=tzutc()), '_value': 6.233333333333333, '_field': 'pm10', '_measurement': 'amsterdam_measurement', 'location': 'Amsterdam-Spaarnwoude', 'unit': 'µg/m³'}
# FluxRecord() table: 21, {'result': '_result', 'table': 21, '_start': datetime.datetime(2024, 4, 23, 11, 22, 34, 375667, tzinfo=tzutc()), '_stop': datetime.datetime(2024, 4, 23, 11, 32, 34, 375667, tzinfo=tzutc()), '_time': datetime.datetime(2024, 4, 23, 11, 32, 27, 889290, tzinfo=tzutc()), '_value': 2.930769230769231, '_field': 'pm25', '_measurement': 'amsterdam_measurement', 'location': 'Amsterdam-Spaarnwoude', 'unit': 'µg/m³'}
# FluxRecord() table: 22, {'result': '_result', 'table': 22, '_start': datetime.datetime(2024, 4, 23, 11, 22, 34, 375667, tzinfo=tzutc()), '_stop': datetime.datetime(2024, 4, 23, 11, 32, 34, 375667, tzinfo=tzutc()), '_time': datetime.datetime(2024, 4, 23, 11, 32, 27, 917958, tzinfo=tzutc()), '_value': 10.3, '_field': 'no2', '_measurement': 'amsterdam_measurement', 'location': 'Amsterdam-Sportpark Ookmeer (Osdorp)', 'unit': 'µg/m³'}
# FluxRecord() table: 23, {'result': '_result', 'table': 23, '_start': datetime.datetime(2024, 4, 23, 11, 22, 34, 375667, tzinfo=tzutc()), '_stop': datetime.datetime(2024, 4, 23, 11, 32, 34, 375667, tzinfo=tzutc()), '_time': datetime.datetime(2024, 4, 23, 11, 32, 27, 920945, tzinfo=tzutc()), '_value': 18.153846153846153, '_field': 'no2', '_measurement': 'amsterdam_measurement', 'location': 'Amsterdam-Stadhouderskade', 'unit': 'µg/m³'}
# FluxRecord() table: 24, {'result': '_result', 'table': 24, '_start': datetime.datetime(2024, 4, 23, 11, 22, 34, 375667, tzinfo=tzutc()), '_stop': datetime.datetime(2024, 4, 23, 11, 32, 34, 375667, tzinfo=tzutc()), '_time': datetime.datetime(2024, 4, 23, 11, 32, 27, 924803, tzinfo=tzutc()), '_value': 7.191666666666666, '_field': 'pm10', '_measurement': 'amsterdam_measurement', 'location': 'Amsterdam-Stadhouderskade', 'unit': 'µg/m³'}
# FluxRecord() table: 25, {'result': '_result', 'table': 25, '_start': datetime.datetime(2024, 4, 23, 11, 22, 34, 375667, tzinfo=tzutc()), '_stop': datetime.datetime(2024, 4, 23, 11, 32, 34, 375667, tzinfo=tzutc()), '_time': datetime.datetime(2024, 4, 23, 11, 32, 27, 930126, tzinfo=tzutc()), '_value': 4.923076923076923, '_field': 'pm25', '_measurement': 'amsterdam_measurement', 'location': 'Amsterdam-Stadhouderskade', 'unit': 'µg/m³'}
# FluxRecord() table: 26, {'result': '_result', 'table': 26, '_start': datetime.datetime(2024, 4, 23, 11, 22, 34, 375667, tzinfo=tzutc()), '_stop': datetime.datetime(2024, 4, 23, 11, 32, 34, 375667, tzinfo=tzutc()), '_time': datetime.datetime(2024, 4, 23, 11, 32, 27, 821455, tzinfo=tzutc()), '_value': 9.192307692307692, '_field': 'no2', '_measurement': 'amsterdam_measurement', 'location': 'Amsterdam-Van Diemenstraat', 'unit': 'µg/m³'}
# FluxRecord() table: 27, {'result': '_result', 'table': 27, '_start': datetime.datetime(2024, 4, 23, 11, 22, 34, 375667, tzinfo=tzutc()), '_stop': datetime.datetime(2024, 4, 23, 11, 32, 34, 375667, tzinfo=tzutc()), '_time': datetime.datetime(2024, 4, 23, 11, 32, 27, 825716, tzinfo=tzutc()), '_value': 90.53076923076924, '_field': 'o3', '_measurement': 'amsterdam_measurement', 'location': 'Amsterdam-Van Diemenstraat', 'unit': 'µg/m³'}
# FluxRecord() table: 28, {'result': '_result', 'table': 28, '_start': datetime.datetime(2024, 4, 23, 11, 22, 34, 375667, tzinfo=tzutc()), '_stop': datetime.datetime(2024, 4, 23, 11, 32, 34, 375667, tzinfo=tzutc()), '_time': datetime.datetime(2024, 4, 23, 11, 32, 27, 829506, tzinfo=tzutc()), '_value': 6.75, '_field': 'pm10', '_measurement': 'amsterdam_measurement', 'location': 'Amsterdam-Van Diemenstraat', 'unit': 'µg/m³'}
# FluxRecord() table: 29, {'result': '_result', 'table': 29, '_start': datetime.datetime(2024, 4, 23, 11, 22, 34, 375667, tzinfo=tzutc()), '_stop': datetime.datetime(2024, 4, 23, 11, 32, 34, 375667, tzinfo=tzutc()), '_time': datetime.datetime(2024, 4, 23, 11, 32, 27, 833347, tzinfo=tzutc()), '_value': 2.8846153846153846, '_field': 'pm25', '_measurement': 'amsterdam_measurement', 'location': 'Amsterdam-Van Diemenstraat', 'unit': 'µg/m³'}
# FluxRecord() table: 30, {'result': '_result', 'table': 30, '_start': datetime.datetime(2024, 4, 23, 11, 22, 34, 375667, tzinfo=tzutc()), '_stop': datetime.datetime(2024, 4, 23, 11, 32, 34, 375667, tzinfo=tzutc()), '_time': datetime.datetime(2024, 4, 23, 11, 32, 27, 836993, tzinfo=tzutc()), '_value': 10.553846153846154, '_field': 'no2', '_measurement': 'amsterdam_measurement', 'location': 'Amsterdam-Vondelpark', 'unit': 'µg/m³'}
# FluxRecord() table: 31, {'result': '_result', 'table': 31, '_start': datetime.datetime(2024, 4, 23, 11, 22, 34, 375667, tzinfo=tzutc()), '_stop': datetime.datetime(2024, 4, 23, 11, 32, 34, 375667, tzinfo=tzutc()), '_time': datetime.datetime(2024, 4, 23, 11, 32, 27, 840187, tzinfo=tzutc()), '_value': 93.15, '_field': 'o3', '_measurement': 'amsterdam_measurement', 'location': 'Amsterdam-Vondelpark', 'unit': 'µg/m³'}
# FluxRecord() table: 32, {'result': '_result', 'table': 32, '_start': datetime.datetime(2024, 4, 23, 11, 22, 34, 375667, tzinfo=tzutc()), '_stop': datetime.datetime(2024, 4, 23, 11, 32, 34, 375667, tzinfo=tzutc()), '_time': datetime.datetime(2024, 4, 23, 11, 32, 27, 843523, tzinfo=tzutc()), '_value': 10.408333333333333, '_field': 'pm10', '_measurement': 'amsterdam_measurement', 'location': 'Amsterdam-Vondelpark', 'unit': 'µg/m³'}
# FluxRecord() table: 33, {'result': '_result', 'table': 33, '_start': datetime.datetime(2024, 4, 23, 11, 22, 34, 375667, tzinfo=tzutc()), '_stop': datetime.datetime(2024, 4, 23, 11, 32, 34, 375667, tzinfo=tzutc()), '_time': datetime.datetime(2024, 4, 23, 11, 32, 27, 847306, tzinfo=tzutc()), '_value': 6.200000000000001, '_field': 'pm25', '_measurement': 'amsterdam_measurement', 'location': 'Amsterdam-Vondelpark', 'unit': 'µg/m³'}
# FluxRecord() table: 34, {'result': '_result', 'table': 34, '_start': datetime.datetime(2024, 4, 23, 11, 22, 34, 375667, tzinfo=tzutc()), '_stop': datetime.datetime(2024, 4, 23, 11, 32, 34, 375667, tzinfo=tzutc()), '_time': datetime.datetime(2024, 4, 23, 11, 32, 27, 851039, tzinfo=tzutc()), '_value': 10.958333333333334, '_field': 'pm10', '_measurement': 'amsterdam_measurement', 'location': 'Amsterdam-Westerpark', 'unit': 'µg/m³'}
# FluxRecord() table: 35, {'result': '_result', 'table': 35, '_start': datetime.datetime(2024, 4, 23, 11, 22, 34, 375667, tzinfo=tzutc()), '_stop': datetime.datetime(2024, 4, 23, 11, 32, 34, 375667, tzinfo=tzutc()), '_time': datetime.datetime(2024, 4, 23, 11, 32, 27, 854021, tzinfo=tzutc()), '_value': 3.423076923076923, '_field': 'pm25', '_measurement': 'amsterdam_measurement', 'location': 'Amsterdam-Westerpark', 'unit': 'µg/m³'}
# FluxRecord() table: 36, {'result': '_result', 'table': 36, '_start': datetime.datetime(2024, 4, 23, 11, 22, 34, 375667, tzinfo=tzutc()), '_stop': datetime.datetime(2024, 4, 23, 11, 32, 34, 375667, tzinfo=tzutc()), '_time': datetime.datetime(2024, 4, 23, 11, 32, 27, 856829, tzinfo=tzutc()), '_value': 2.453846153846154, '_field': 'so2', '_measurement': 'amsterdam_measurement', 'location': 'Amsterdam-Westerpark', 'unit': 'µg/m³'}

# %% [markdown]
# aggregate data

# %%
query_api = client.query_api()

query = """from(bucket: "Demo_Data_Pipeline")
  |> range(start: -24h)
  |> filter(fn: (r) => r._measurement == "amsterdam_measurement")
  |> mean()"""
tables = query_api.query(query, org="ORG_NAME")

for table in tables:
    for record in table.records:
        print(record)
# Out:
# FluxRecord() table: 0, {'result': '_result', 'table': 0, '_start': datetime.datetime(2024, 4, 22, 9, 23, 58, 684730, tzinfo=tzutc()), '_stop': datetime.datetime(2024, 4, 23, 9, 23, 58, 684730, tzinfo=tzutc()), '_value': 40.775, '_field': 'no2', '_measurement': 'amsterdam_measurement', 'location': 'Amsterdam-Einsteinweg', 'unit': 'µg/m³'}
# FluxRecord() table: 1, {'result': '_result', 'table': 1, '_start': datetime.datetime(2024, 4, 22, 9, 23, 58, 684730, tzinfo=tzutc()), '_stop': datetime.datetime(2024, 4, 23, 9, 23, 58, 684730, tzinfo=tzutc()), '_value': 13.375155279503105, '_field': 'pm10', '_measurement': 'amsterdam_measurement', 'location': 'Amsterdam-Einsteinweg', 'unit': 'µg/m³'}
# FluxRecord() table: 2, {'result': '_result', 'table': 2, '_start': datetime.datetime(2024, 4, 22, 9, 23, 58, 684730, tzinfo=tzutc()), '_stop': datetime.datetime(2024, 4, 23, 9, 23, 58, 684730, tzinfo=tzutc()), '_value': 7.437101449275363, '_field': 'pm25', '_measurement': 'amsterdam_measurement', 'location': 'Amsterdam-Einsteinweg', 'unit': 'µg/m³'}
# FluxRecord() table: 3, {'result': '_result', 'table': 3, '_start': datetime.datetime(2024, 4, 22, 9, 23, 58, 684730, tzinfo=tzutc()), '_stop': datetime.datetime(2024, 4, 23, 9, 23, 58, 684730, tzinfo=tzutc()), '_value': 13.523247863247866, '_field': 'no2', '_measurement': 'amsterdam_measurement', 'location': 'Amsterdam-General', 'unit': 'µg/m³'}
# FluxRecord() table: 4, {'result': '_result', 'table': 4, '_start': datetime.datetime(2024, 4, 22, 9, 23, 58, 684730, tzinfo=tzutc()), '_stop': datetime.datetime(2024, 4, 23, 9, 23, 58, 684730, tzinfo=tzutc()), '_value': 89.04222222222222, '_field': 'o3', '_measurement': 'amsterdam_measurement', 'location': 'Amsterdam-General', 'unit': 'µg/m³'}
# FluxRecord() table: 5, {'result': '_result', 'table': 5, '_start': datetime.datetime(2024, 4, 22, 9, 23, 58, 684730, tzinfo=tzutc()), '_stop': datetime.datetime(2024, 4, 23, 9, 23, 58, 684730, tzinfo=tzutc()), '_value': 8.499107142857143, '_field': 'pm10', '_measurement': 'amsterdam_measurement', 'location': 'Amsterdam-General', 'unit': 'µg/m³'}
# FluxRecord() table: 6, {'result': '_result', 'table': 6, '_start': datetime.datetime(2024, 4, 22, 9, 23, 58, 684730, tzinfo=tzutc()), '_stop': datetime.datetime(2024, 4, 23, 9, 23, 58, 684730, tzinfo=tzutc()), '_value': 4.662857142857143, '_field': 'pm25', '_measurement': 'amsterdam_measurement', 'location': 'Amsterdam-General', 'unit': 'µg/m³'}
# FluxRecord() table: 7, {'result': '_result', 'table': 7, '_start': datetime.datetime(2024, 4, 22, 9, 23, 58, 684730, tzinfo=tzutc()), '_stop': datetime.datetime(2024, 4, 23, 9, 23, 58, 684730, tzinfo=tzutc()), '_value': 1.25, '_field': 'so2', '_measurement': 'amsterdam_measurement', 'location': 'Amsterdam-General', 'unit': 'µg/m³'}
# FluxRecord() table: 8, {'result': '_result', 'table': 8, '_start': datetime.datetime(2024, 4, 22, 9, 23, 58, 684730, tzinfo=tzutc()), '_stop': datetime.datetime(2024, 4, 23, 9, 23, 58, 684730, tzinfo=tzutc()), '_value': 20.704166666666666, '_field': 'no2', '_measurement': 'amsterdam_measurement', 'location': 'Amsterdam-Haarlemmerweg', 'unit': 'µg/m³'}
# FluxRecord() table: 9, {'result': '_result', 'table': 9, '_start': datetime.datetime(2024, 4, 22, 9, 23, 58, 684730, tzinfo=tzutc()), '_stop': datetime.datetime(2024, 4, 23, 9, 23, 58, 684730, tzinfo=tzutc()), '_value': 10.605833333333333, '_field': 'no2', '_measurement': 'amsterdam_measurement', 'location': 'Amsterdam-Hoogtij', 'unit': 'µg/m³'}
# FluxRecord() table: 10, {'result': '_result', 'table': 10, '_start': datetime.datetime(2024, 4, 22, 9, 23, 58, 684730, tzinfo=tzutc()), '_stop': datetime.datetime(2024, 4, 23, 9, 23, 58, 684730, tzinfo=tzutc()), '_value': 6.392559523809524, '_field': 'pm10', '_measurement': 'amsterdam_measurement', 'location': 'Amsterdam-Hoogtij', 'unit': 'µg/m³'}
# FluxRecord() table: 11, {'result': '_result', 'table': 11, '_start': datetime.datetime(2024, 4, 22, 9, 23, 58, 684730, tzinfo=tzutc()), '_stop': datetime.datetime(2024, 4, 23, 9, 23, 58, 684730, tzinfo=tzutc()), '_value': 2.9858333333333333, '_field': 'pm25', '_measurement': 'amsterdam_measurement', 'location': 'Amsterdam-Hoogtij', 'unit': 'µg/m³'}
# FluxRecord() table: 12, {'result': '_result', 'table': 12, '_start': datetime.datetime(2024, 4, 22, 9, 23, 58, 684730, tzinfo=tzutc()), '_stop': datetime.datetime(2024, 4, 23, 9, 23, 58, 684730, tzinfo=tzutc()), '_value': 0.17, '_field': 'so2', '_measurement': 'amsterdam_measurement', 'location': 'Amsterdam-Hoogtij', 'unit': 'µg/m³'}
# FluxRecord() table: 13, {'result': '_result', 'table': 13, '_start': datetime.datetime(2024, 4, 22, 9, 23, 58, 684730, tzinfo=tzutc()), '_stop': datetime.datetime(2024, 4, 23, 9, 23, 58, 684730, tzinfo=tzutc()), '_value': 21.32625, '_field': 'no2', '_measurement': 'amsterdam_measurement', 'location': 'Amsterdam-Jan van Galenstraat', 'unit': 'µg/m³'}
# FluxRecord() table: 14, {'result': '_result', 'table': 14, '_start': datetime.datetime(2024, 4, 22, 9, 23, 58, 684730, tzinfo=tzutc()), '_stop': datetime.datetime(2024, 4, 23, 9, 23, 58, 684730, tzinfo=tzutc()), '_value': 8.010416666666666, '_field': 'pm10', '_measurement': 'amsterdam_measurement', 'location': 'Amsterdam-Jan van Galenstraat', 'unit': 'µg/m³'}
# FluxRecord() table: 15, {'result': '_result', 'table': 15, '_start': datetime.datetime(2024, 4, 22, 9, 23, 58, 684730, tzinfo=tzutc()), '_stop': datetime.datetime(2024, 4, 23, 9, 23, 58, 684730, tzinfo=tzutc()), '_value': 6.290000000000001, '_field': 'no2', '_measurement': 'amsterdam_measurement', 'location': 'Amsterdam-Kantershof (Zuid Oost)', 'unit': 'µg/m³'}
# FluxRecord() table: 16, {'result': '_result', 'table': 16, '_start': datetime.datetime(2024, 4, 22, 9, 23, 58, 684730, tzinfo=tzutc()), '_stop': datetime.datetime(2024, 4, 23, 9, 23, 58, 684730, tzinfo=tzutc()), '_value': 6.007916666666667, '_field': 'no2', '_measurement': 'amsterdam_measurement', 'location': 'Amsterdam-Nieuwendammerdijk', 'unit': 'µg/m³'}
# FluxRecord() table: 17, {'result': '_result', 'table': 17, '_start': datetime.datetime(2024, 4, 22, 9, 23, 58, 684730, tzinfo=tzutc()), '_stop': datetime.datetime(2024, 4, 23, 9, 23, 58, 684730, tzinfo=tzutc()), '_value': 80.9675, '_field': 'o3', '_measurement': 'amsterdam_measurement', 'location': 'Amsterdam-Nieuwendammerdijk', 'unit': 'µg/m³'}
# FluxRecord() table: 18, {'result': '_result', 'table': 18, '_start': datetime.datetime(2024, 4, 22, 9, 23, 58, 684730, tzinfo=tzutc()), '_stop': datetime.datetime(2024, 4, 23, 9, 23, 58, 684730, tzinfo=tzutc()), '_value': 13.33875, '_field': 'no2', '_measurement': 'amsterdam_measurement', 'location': 'Amsterdam-Oude Schans', 'unit': 'µg/m³'}
# FluxRecord() table: 19, {'result': '_result', 'table': 19, '_start': datetime.datetime(2024, 4, 22, 9, 23, 58, 684730, tzinfo=tzutc()), '_stop': datetime.datetime(2024, 4, 23, 9, 23, 58, 684730, tzinfo=tzutc()), '_value': 10.939166666666667, '_field': 'no2', '_measurement': 'amsterdam_measurement', 'location': 'Amsterdam-Spaarnwoude', 'unit': 'µg/m³'}
# FluxRecord() table: 20, {'result': '_result', 'table': 20, '_start': datetime.datetime(2024, 4, 22, 9, 23, 58, 684730, tzinfo=tzutc()), '_stop': datetime.datetime(2024, 4, 23, 9, 23, 58, 684730, tzinfo=tzutc()), '_value': 6.201785714285714, '_field': 'pm10', '_measurement': 'amsterdam_measurement', 'location': 'Amsterdam-Spaarnwoude', 'unit': 'µg/m³'}
# FluxRecord() table: 21, {'result': '_result', 'table': 21, '_start': datetime.datetime(2024, 4, 22, 9, 23, 58, 684730, tzinfo=tzutc()), '_stop': datetime.datetime(2024, 4, 23, 9, 23, 58, 684730, tzinfo=tzutc()), '_value': 2.9320833333333334, '_field': 'pm25', '_measurement': 'amsterdam_measurement', 'location': 'Amsterdam-Spaarnwoude', 'unit': 'µg/m³'}
# FluxRecord() table: 22, {'result': '_result', 'table': 22, '_start': datetime.datetime(2024, 4, 22, 9, 23, 58, 684730, tzinfo=tzutc()), '_stop': datetime.datetime(2024, 4, 23, 9, 23, 58, 684730, tzinfo=tzutc()), '_value': 13.145416666666666, '_field': 'no2', '_measurement': 'amsterdam_measurement', 'location': 'Amsterdam-Sportpark Ookmeer (Osdorp)', 'unit': 'µg/m³'}
# FluxRecord() table: 23, {'result': '_result', 'table': 23, '_start': datetime.datetime(2024, 4, 22, 9, 23, 58, 684730, tzinfo=tzutc()), '_stop': datetime.datetime(2024, 4, 23, 9, 23, 58, 684730, tzinfo=tzutc()), '_value': 20.657916666666665, '_field': 'no2', '_measurement': 'amsterdam_measurement', 'location': 'Amsterdam-Stadhouderskade', 'unit': 'µg/m³'}
# FluxRecord() table: 24, {'result': '_result', 'table': 24, '_start': datetime.datetime(2024, 4, 22, 9, 23, 58, 684730, tzinfo=tzutc()), '_stop': datetime.datetime(2024, 4, 23, 9, 23, 58, 684730, tzinfo=tzutc()), '_value': 8.499404761904762, '_field': 'pm10', '_measurement': 'amsterdam_measurement', 'location': 'Amsterdam-Stadhouderskade', 'unit': 'µg/m³'}
# FluxRecord() table: 25, {'result': '_result', 'table': 25, '_start': datetime.datetime(2024, 4, 22, 9, 23, 58, 684730, tzinfo=tzutc()), '_stop': datetime.datetime(2024, 4, 23, 9, 23, 58, 684730, tzinfo=tzutc()), '_value': 5.361594202898551, '_field': 'pm25', '_measurement': 'amsterdam_measurement', 'location': 'Amsterdam-Stadhouderskade', 'unit': 'µg/m³'}
# FluxRecord() table: 26, {'result': '_result', 'table': 26, '_start': datetime.datetime(2024, 4, 22, 9, 23, 58, 684730, tzinfo=tzutc()), '_stop': datetime.datetime(2024, 4, 23, 9, 23, 58, 684730, tzinfo=tzutc()), '_value': 11.038653846153846, '_field': 'no2', '_measurement': 'amsterdam_measurement', 'location': 'Amsterdam-Van Diemenstraat', 'unit': 'µg/m³'}
# FluxRecord() table: 27, {'result': '_result', 'table': 27, '_start': datetime.datetime(2024, 4, 22, 9, 23, 58, 684730, tzinfo=tzutc()), '_stop': datetime.datetime(2024, 4, 23, 9, 23, 58, 684730, tzinfo=tzutc()), '_value': 82.66041666666666, '_field': 'o3', '_measurement': 'amsterdam_measurement', 'location': 'Amsterdam-Van Diemenstraat', 'unit': 'µg/m³'}
# FluxRecord() table: 28, {'result': '_result', 'table': 28, '_start': datetime.datetime(2024, 4, 22, 9, 23, 58, 684730, tzinfo=tzutc()), '_stop': datetime.datetime(2024, 4, 23, 9, 23, 58, 684730, tzinfo=tzutc()), '_value': 8.517559523809524, '_field': 'pm10', '_measurement': 'amsterdam_measurement', 'location': 'Amsterdam-Van Diemenstraat', 'unit': 'µg/m³'}
# FluxRecord() table: 29, {'result': '_result', 'table': 29, '_start': datetime.datetime(2024, 4, 22, 9, 23, 58, 684730, tzinfo=tzutc()), '_stop': datetime.datetime(2024, 4, 23, 9, 23, 58, 684730, tzinfo=tzutc()), '_value': 3.1158333333333332, '_field': 'pm25', '_measurement': 'amsterdam_measurement', 'location': 'Amsterdam-Van Diemenstraat', 'unit': 'µg/m³'}
# FluxRecord() table: 30, {'result': '_result', 'table': 30, '_start': datetime.datetime(2024, 4, 22, 9, 23, 58, 684730, tzinfo=tzutc()), '_stop': datetime.datetime(2024, 4, 23, 9, 23, 58, 684730, tzinfo=tzutc()), '_value': 13.436249999999998, '_field': 'no2', '_measurement': 'amsterdam_measurement', 'location': 'Amsterdam-Vondelpark', 'unit': 'µg/m³'}
# FluxRecord() table: 31, {'result': '_result', 'table': 31, '_start': datetime.datetime(2024, 4, 22, 9, 23, 58, 684730, tzinfo=tzutc()), '_stop': datetime.datetime(2024, 4, 23, 9, 23, 58, 684730, tzinfo=tzutc()), '_value': 64.88749999999999, '_field': 'o3', '_measurement': 'amsterdam_measurement', 'location': 'Amsterdam-Vondelpark', 'unit': 'µg/m³'}
# FluxRecord() table: 32, {'result': '_result', 'table': 32, '_start': datetime.datetime(2024, 4, 22, 9, 23, 58, 684730, tzinfo=tzutc()), '_stop': datetime.datetime(2024, 4, 23, 9, 23, 58, 684730, tzinfo=tzutc()), '_value': 11.735416666666666, '_field': 'pm10', '_measurement': 'amsterdam_measurement', 'location': 'Amsterdam-Vondelpark', 'unit': 'µg/m³'}
# FluxRecord() table: 33, {'result': '_result', 'table': 33, '_start': datetime.datetime(2024, 4, 22, 9, 23, 58, 684730, tzinfo=tzutc()), '_stop': datetime.datetime(2024, 4, 23, 9, 23, 58, 684730, tzinfo=tzutc()), '_value': 6.785416666666666, '_field': 'pm25', '_measurement': 'amsterdam_measurement', 'location': 'Amsterdam-Vondelpark', 'unit': 'µg/m³'}
# FluxRecord() table: 34, {'result': '_result', 'table': 34, '_start': datetime.datetime(2024, 4, 22, 9, 23, 58, 684730, tzinfo=tzutc()), '_stop': datetime.datetime(2024, 4, 23, 9, 23, 58, 684730, tzinfo=tzutc()), '_value': 10.589583333333334, '_field': 'pm10', '_measurement': 'amsterdam_measurement', 'location': 'Amsterdam-Westerpark', 'unit': 'µg/m³'}
# FluxRecord() table: 35, {'result': '_result', 'table': 35, '_start': datetime.datetime(2024, 4, 22, 9, 23, 58, 684730, tzinfo=tzutc()), '_stop': datetime.datetime(2024, 4, 23, 9, 23, 58, 684730, tzinfo=tzutc()), '_value': 3.6483333333333334, '_field': 'pm25', '_measurement': 'amsterdam_measurement', 'location': 'Amsterdam-Westerpark', 'unit': 'µg/m³'}
# FluxRecord() table: 36, {'result': '_result', 'table': 36, '_start': datetime.datetime(2024, 4, 22, 9, 23, 58, 684730, tzinfo=tzutc()), '_stop': datetime.datetime(2024, 4, 23, 9, 23, 58, 684730, tzinfo=tzutc()), '_value': 2.244583333333333, '_field': 'so2', '_measurement': 'amsterdam_measurement', 'location': 'Amsterdam-Westerpark', 'unit': 'µg/m³'}

# %% [markdown]
# delete data

# %%
# Specify the start and end time for the data deletion
start_time = datetime(2024, 4, 22, 14, 55, 0)  # Replace with your start time
end_time = datetime(2024, 4, 22, 15, 5, 0)    # Replace with your end time

# Create a DeletePredicateRequest to specify the predicate for data deletion
delete_request = DeletePredicateRequest()
delete_request.start = start_time
delete_request.stop = end_time
delete_request.predicate = '_measurement="' + "measurement1" + '"'

client.delete_api
